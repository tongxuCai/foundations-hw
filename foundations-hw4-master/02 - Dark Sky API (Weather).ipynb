# %% [markdown]
# # Dark Sky API (Weather)
#
# Answer the following questions using the [Dark Sky API](https://darksky.net/dev/). I've added three cells for each question but you're free to use more or less! Hold `Shift` and hit `Enter` to run a cell, and use the `+` on the top left to add a new cell to a notebook.
#
# If you spend some time reading the documentation your life will probably be a little bit easier!
#
# ## 0) Import any libraries you might need
#
# - *Tip: We're going to be downloading things from the internet, so we probably need `requests`.*

# %%
import requests

# %% [markdown]
# ## 1) Make a request from the Dark Sky API for where you were born (or lived, or want to visit!).
#
# - *Tip: The URL we used in class was for a place near San Francisco. What was the format of the endpoint that made this happen?*
# - *Tip: Save the URL as a separate variable, and be sure to not have `[` and `]` inside.*
# - *Tip: How is north vs. south and east vs. west latitude/longitude represented? Is it the normal North/South/East/West?*
# - *Tip: You know it's JSON, but Python doesn't! Make sure you aren't trying to deal with plain text.*
# - *Tip: Once you've imported the JSON into a variable, check the timezone's name to make sure it seems like it got the right part of the world!*

# %%
from dotenv import load_dotenv
load_dotenv()
import os
API_KEY=os.getenv('DARKSKY_API_KEY')
API_KEY

# %%
import requests
API_KEY='9d7e3d75a20e0e7491a8bc3a046011a8'

# %%
response=requests.get(f'https://api.darksky.net/forecast/{API_KEY}/40,-74')
newyork=response.json()
newyork
# Out:
# {'latitude': 40,
#  'longitude': -74,
#  'timezone': 'America/New_York',
#  'currently': {'time': 1560017746,
#   'summary': 'Clear',
#   'icon': 'clear-day',
#   'nearestStormDistance': 49,
#   'nearestStormBearing': 156,
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 67.07,
#   'apparentTemperature': 67.07,
#   'dewPoint': 58.79,
#   'humidity': 0.75,
#   'pressure': 1020.93,
#   'windSpeed': 10.4,
#   'windGust': 16.55,
#   'windBearing': 47,
#   'cloudCover': 0,
#   'uvIndex': 9,
#   'visibility': 5.48,
#   'ozone': 328.22},
#  'minutely': {'summary': 'Clear for the hour.',
#   'icon': 'clear-day',
#   'data': [{'time': 1560017700, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560017760, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560017820, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560017880, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560017940, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560018000, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560018060, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560018120, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560018180, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560018240, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560018300, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560018360, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560018420, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560018480, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560018540, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560018600, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560018660, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560018720, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560018780, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560018840, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560018900, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560018960, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560019020, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560019080, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560019140, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560019200, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560019260, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560019320, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560019380, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560019440, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560019500, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560019560, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560019620, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560019680, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560019740, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560019800, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560019860, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560019920, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560019980, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560020040, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560020100, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560020160, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560020220, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560020280, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560020340, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560020400, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560020460, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560020520, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560020580, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560020640, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560020700, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560020760, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560020820, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560020880, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560020940, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560021000, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560021060, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560021120, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560021180, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560021240, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560021300, 'precipIntensity': 0, 'precipProbability': 0}]},
#  'hourly': {'summary': 'Mostly cloudy starting this evening and breezy starting tomorrow morning.',
#   'icon': 'wind',
#   'data': [{'time': 1560016800,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 66.92,
#     'apparentTemperature': 66.92,
#     'dewPoint': 58.93,
#     'humidity': 0.76,
#     'pressure': 1020.87,
#     'windSpeed': 10.34,
#     'windGust': 16.33,
#     'windBearing': 45,
#     'cloudCover': 0,
#     'uvIndex': 9,
#     'visibility': 5.03,
#     'ozone': 328.54},
#    {'time': 1560020400,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 67.48,
#     'apparentTemperature': 67.48,
#     'dewPoint': 58.37,
#     'humidity': 0.73,
#     'pressure': 1021.1,
#     'windSpeed': 10.64,
#     'windGust': 17.17,
#     'windBearing': 54,
#     'cloudCover': 0,
#     'uvIndex': 8,
#     'visibility': 6.73,
#     'ozone': 327.32},
#    {'time': 1560024000,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0.0017,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 68.22,
#     'apparentTemperature': 68.22,
#     'dewPoint': 58.31,
#     'humidity': 0.71,
#     'pressure': 1021.29,
#     'windSpeed': 13.08,
#     'windGust': 20.39,
#     'windBearing': 69,
#     'cloudCover': 0.01,
#     'uvIndex': 5,
#     'visibility': 10,
#     'ozone': 328.24},
#    {'time': 1560027600,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0005,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 68.65,
#     'apparentTemperature': 68.65,
#     'dewPoint': 58.33,
#     'humidity': 0.7,
#     'pressure': 1021.79,
#     'windSpeed': 14.9,
#     'windGust': 23.11,
#     'windBearing': 77,
#     'cloudCover': 0.29,
#     'uvIndex': 3,
#     'visibility': 10,
#     'ozone': 332.2},
#    {'time': 1560031200,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 68.42,
#     'apparentTemperature': 68.42,
#     'dewPoint': 58.14,
#     'humidity': 0.7,
#     'pressure': 1022.13,
#     'windSpeed': 14.75,
#     'windGust': 24.49,
#     'windBearing': 80,
#     'cloudCover': 0.46,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 329.87},
#    {'time': 1560034800,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0018,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperature': 67.68,
#     'apparentTemperature': 67.68,
#     'dewPoint': 58.09,
#     'humidity': 0.71,
#     'pressure': 1022.13,
#     'windSpeed': 14.31,
#     'windGust': 23.46,
#     'windBearing': 84,
#     'cloudCover': 0.57,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 330.48},
#    {'time': 1560038400,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0015,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperature': 67.18,
#     'apparentTemperature': 67.18,
#     'dewPoint': 58.03,
#     'humidity': 0.73,
#     'pressure': 1022.31,
#     'windSpeed': 14.28,
#     'windGust': 23.08,
#     'windBearing': 92,
#     'cloudCover': 0.59,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 334.12},
#    {'time': 1560042000,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0027,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperature': 66.85,
#     'apparentTemperature': 66.85,
#     'dewPoint': 58,
#     'humidity': 0.73,
#     'pressure': 1022.7,
#     'windSpeed': 14.47,
#     'windGust': 22.87,
#     'windBearing': 96,
#     'cloudCover': 0.65,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 331.59},
#    {'time': 1560045600,
#     'summary': 'Breezy and Mostly Cloudy',
#     'icon': 'wind',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 66.63,
#     'apparentTemperature': 66.63,
#     'dewPoint': 57.86,
#     'humidity': 0.73,
#     'pressure': 1023.19,
#     'windSpeed': 15.09,
#     'windGust': 22.2,
#     'windBearing': 94,
#     'cloudCover': 0.72,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 332},
#    {'time': 1560049200,
#     'summary': 'Breezy and Mostly Cloudy',
#     'icon': 'wind',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 66.54,
#     'apparentTemperature': 66.54,
#     'dewPoint': 57.79,
#     'humidity': 0.73,
#     'pressure': 1023.33,
#     'windSpeed': 15.37,
#     'windGust': 23.43,
#     'windBearing': 94,
#     'cloudCover': 0.77,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 334.32},
#    {'time': 1560052800,
#     'summary': 'Breezy and Mostly Cloudy',
#     'icon': 'wind',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 66.33,
#     'apparentTemperature': 66.33,
#     'dewPoint': 57.96,
#     'humidity': 0.74,
#     'pressure': 1023.6,
#     'windSpeed': 15.15,
#     'windGust': 22.83,
#     'windBearing': 97,
#     'cloudCover': 0.77,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 332},
#    {'time': 1560056400,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 66.26,
#     'apparentTemperature': 66.26,
#     'dewPoint': 58.06,
#     'humidity': 0.75,
#     'pressure': 1023.6,
#     'windSpeed': 14.96,
#     'windGust': 23.22,
#     'windBearing': 97,
#     'cloudCover': 0.76,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 331.59},
#    {'time': 1560060000,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 66.32,
#     'apparentTemperature': 66.32,
#     'dewPoint': 58.06,
#     'humidity': 0.75,
#     'pressure': 1023.37,
#     'windSpeed': 14.78,
#     'windGust': 24.13,
#     'windBearing': 99,
#     'cloudCover': 0.76,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 333.92},
#    {'time': 1560063600,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0013,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperature': 66.2,
#     'apparentTemperature': 66.2,
#     'dewPoint': 58.38,
#     'humidity': 0.76,
#     'pressure': 1023.46,
#     'windSpeed': 14.07,
#     'windGust': 21.58,
#     'windBearing': 97,
#     'cloudCover': 0.78,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 331.19},
#    {'time': 1560067200,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 66.12,
#     'apparentTemperature': 66.12,
#     'dewPoint': 58.85,
#     'humidity': 0.77,
#     'pressure': 1023.87,
#     'windSpeed': 14.1,
#     'windGust': 19.55,
#     'windBearing': 94,
#     'cloudCover': 0.72,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 331.19},
#    {'time': 1560070800,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 66.34,
#     'apparentTemperature': 66.34,
#     'dewPoint': 58.96,
#     'humidity': 0.77,
#     'pressure': 1024.1,
#     'windSpeed': 14.19,
#     'windGust': 19.95,
#     'windBearing': 90,
#     'cloudCover': 0.74,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 331.29},
#    {'time': 1560074400,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 66.86,
#     'apparentTemperature': 66.86,
#     'dewPoint': 58.9,
#     'humidity': 0.76,
#     'pressure': 1024.42,
#     'windSpeed': 14.87,
#     'windGust': 21.31,
#     'windBearing': 85,
#     'cloudCover': 0.73,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 331.8},
#    {'time': 1560078000,
#     'summary': 'Breezy and Mostly Cloudy',
#     'icon': 'wind',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 67.6,
#     'apparentTemperature': 67.6,
#     'dewPoint': 58.72,
#     'humidity': 0.73,
#     'pressure': 1024.85,
#     'windSpeed': 15.94,
#     'windGust': 23.15,
#     'windBearing': 82,
#     'cloudCover': 0.7,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 332.5},
#    {'time': 1560081600,
#     'summary': 'Breezy and Mostly Cloudy',
#     'icon': 'wind',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 68.39,
#     'apparentTemperature': 68.39,
#     'dewPoint': 58.51,
#     'humidity': 0.71,
#     'pressure': 1025.27,
#     'windSpeed': 16.83,
#     'windGust': 24.63,
#     'windBearing': 80,
#     'cloudCover': 0.68,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 332.81},
#    {'time': 1560085200,
#     'summary': 'Breezy and Mostly Cloudy',
#     'icon': 'wind',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 69.29,
#     'apparentTemperature': 69.29,
#     'dewPoint': 58.25,
#     'humidity': 0.68,
#     'pressure': 1025.7,
#     'windSpeed': 17.31,
#     'windGust': 25.39,
#     'windBearing': 81,
#     'cloudCover': 0.66,
#     'uvIndex': 3,
#     'visibility': 10,
#     'ozone': 332.4},
#    {'time': 1560088800,
#     'summary': 'Breezy and Mostly Cloudy',
#     'icon': 'wind',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 70,
#     'apparentTemperature': 70,
#     'dewPoint': 58.01,
#     'humidity': 0.66,
#     'pressure': 1026.09,
#     'windSpeed': 17.57,
#     'windGust': 25.71,
#     'windBearing': 86,
#     'cloudCover': 0.65,
#     'uvIndex': 4,
#     'visibility': 10,
#     'ozone': 331.69},
#    {'time': 1560092400,
#     'summary': 'Breezy and Mostly Cloudy',
#     'icon': 'wind',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 70.3,
#     'apparentTemperature': 70.3,
#     'dewPoint': 57.87,
#     'humidity': 0.65,
#     'pressure': 1026.39,
#     'windSpeed': 17.74,
#     'windGust': 25.86,
#     'windBearing': 89,
#     'cloudCover': 0.64,
#     'uvIndex': 5,
#     'visibility': 10,
#     'ozone': 330.98},
#    {'time': 1560096000,
#     'summary': 'Breezy and Mostly Cloudy',
#     'icon': 'wind',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 69.89,
#     'apparentTemperature': 69.89,
#     'dewPoint': 57.94,
#     'humidity': 0.66,
#     'pressure': 1026.54,
#     'windSpeed': 17.8,
#     'windGust': 25.82,
#     'windBearing': 89,
#     'cloudCover': 0.65,
#     'uvIndex': 6,
#     'visibility': 10,
#     'ozone': 330.37},
#    {'time': 1560099600,
#     'summary': 'Breezy and Mostly Cloudy',
#     'icon': 'wind',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 69.43,
#     'apparentTemperature': 69.43,
#     'dewPoint': 58.16,
#     'humidity': 0.67,
#     'pressure': 1026.54,
#     'windSpeed': 17.77,
#     'windGust': 25.53,
#     'windBearing': 89,
#     'cloudCover': 0.68,
#     'uvIndex': 6,
#     'visibility': 10,
#     'ozone': 329.76},
#    {'time': 1560103200,
#     'summary': 'Breezy and Mostly Cloudy',
#     'icon': 'wind',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 69.48,
#     'apparentTemperature': 69.48,
#     'dewPoint': 58.28,
#     'humidity': 0.68,
#     'pressure': 1026.44,
#     'windSpeed': 17.74,
#     'windGust': 25.21,
#     'windBearing': 89,
#     'cloudCover': 0.7,
#     'uvIndex': 5,
#     'visibility': 10,
#     'ozone': 329.56},
#    {'time': 1560106800,
#     'summary': 'Breezy and Mostly Cloudy',
#     'icon': 'wind',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 69.41,
#     'apparentTemperature': 69.41,
#     'dewPoint': 58.19,
#     'humidity': 0.68,
#     'pressure': 1026.19,
#     'windSpeed': 17.77,
#     'windGust': 24.88,
#     'windBearing': 89,
#     'cloudCover': 0.72,
#     'uvIndex': 5,
#     'visibility': 10,
#     'ozone': 330.17},
#    {'time': 1560110400,
#     'summary': 'Breezy and Mostly Cloudy',
#     'icon': 'wind',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 69.03,
#     'apparentTemperature': 69.03,
#     'dewPoint': 58.03,
#     'humidity': 0.68,
#     'pressure': 1025.9,
#     'windSpeed': 17.8,
#     'windGust': 24.56,
#     'windBearing': 90,
#     'cloudCover': 0.72,
#     'uvIndex': 4,
#     'visibility': 10,
#     'ozone': 331.19},
#    {'time': 1560114000,
#     'summary': 'Breezy and Mostly Cloudy',
#     'icon': 'wind',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 68.65,
#     'apparentTemperature': 68.65,
#     'dewPoint': 57.93,
#     'humidity': 0.69,
#     'pressure': 1025.56,
#     'windSpeed': 17.8,
#     'windGust': 24.31,
#     'windBearing': 92,
#     'cloudCover': 0.74,
#     'uvIndex': 2,
#     'visibility': 10,
#     'ozone': 331.59},
#    {'time': 1560117600,
#     'summary': 'Breezy and Mostly Cloudy',
#     'icon': 'wind',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 68.37,
#     'apparentTemperature': 68.37,
#     'dewPoint': 57.94,
#     'humidity': 0.69,
#     'pressure': 1025.32,
#     'windSpeed': 17.7,
#     'windGust': 24.1,
#     'windBearing': 92,
#     'cloudCover': 0.77,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 330.68},
#    {'time': 1560121200,
#     'summary': 'Breezy and Mostly Cloudy',
#     'icon': 'wind',
#     'precipIntensity': 0.0003,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 67.92,
#     'apparentTemperature': 67.92,
#     'dewPoint': 58.24,
#     'humidity': 0.71,
#     'pressure': 1024.99,
#     'windSpeed': 18.06,
#     'windGust': 24.78,
#     'windBearing': 92,
#     'cloudCover': 0.75,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 327.93},
#    {'time': 1560124800,
#     'summary': 'Breezy and Mostly Cloudy',
#     'icon': 'wind',
#     'precipIntensity': 0.0005,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 67.28,
#     'apparentTemperature': 67.28,
#     'dewPoint': 58.15,
#     'humidity': 0.73,
#     'pressure': 1024.89,
#     'windSpeed': 17.48,
#     'windGust': 23.85,
#     'windBearing': 93,
#     'cloudCover': 0.83,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 327.83},
#    {'time': 1560128400,
#     'summary': 'Breezy and Mostly Cloudy',
#     'icon': 'wind',
#     'precipIntensity': 0.0006,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 67,
#     'apparentTemperature': 67,
#     'dewPoint': 58.33,
#     'humidity': 0.74,
#     'pressure': 1024.8,
#     'windSpeed': 17.51,
#     'windGust': 23.78,
#     'windBearing': 93,
#     'cloudCover': 0.85,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 326.81},
#    {'time': 1560132000,
#     'summary': 'Breezy and Mostly Cloudy',
#     'icon': 'wind',
#     'precipIntensity': 0.0006,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 66.89,
#     'apparentTemperature': 66.89,
#     'dewPoint': 58.72,
#     'humidity': 0.75,
#     'pressure': 1024.61,
#     'windSpeed': 18.26,
#     'windGust': 25.03,
#     'windBearing': 93,
#     'cloudCover': 0.81,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 324.35},
#    {'time': 1560135600,
#     'summary': 'Breezy and Mostly Cloudy',
#     'icon': 'wind',
#     'precipIntensity': 0.0005,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperature': 66.71,
#     'apparentTemperature': 66.71,
#     'dewPoint': 58.94,
#     'humidity': 0.76,
#     'pressure': 1024.38,
#     'windSpeed': 18.29,
#     'windGust': 25.1,
#     'windBearing': 93,
#     'cloudCover': 0.83,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 323.32},
#    {'time': 1560139200,
#     'summary': 'Breezy and Mostly Cloudy',
#     'icon': 'wind',
#     'precipIntensity': 0.0003,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperature': 66.7,
#     'apparentTemperature': 66.7,
#     'dewPoint': 59.1,
#     'humidity': 0.77,
#     'pressure': 1024.01,
#     'windSpeed': 18.09,
#     'windGust': 25.31,
#     'windBearing': 94,
#     'cloudCover': 0.84,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 322.39},
#    {'time': 1560142800,
#     'summary': 'Breezy and Mostly Cloudy',
#     'icon': 'wind',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 66.83,
#     'apparentTemperature': 66.83,
#     'dewPoint': 59.26,
#     'humidity': 0.77,
#     'pressure': 1023.46,
#     'windSpeed': 17.8,
#     'windGust': 25.6,
#     'windBearing': 96,
#     'cloudCover': 0.85,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 321.67},
#    {'time': 1560146400,
#     'summary': 'Breezy and Mostly Cloudy',
#     'icon': 'wind',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 66.99,
#     'apparentTemperature': 67.01,
#     'dewPoint': 59.55,
#     'humidity': 0.77,
#     'pressure': 1022.88,
#     'windSpeed': 17.48,
#     'windGust': 25.75,
#     'windBearing': 97,
#     'cloudCover': 0.86,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 321.46},
#    {'time': 1560150000,
#     'summary': 'Breezy and Mostly Cloudy',
#     'icon': 'wind',
#     'precipIntensity': 0.0005,
#     'precipProbability': 0.06,
#     'precipType': 'rain',
#     'temperature': 67.11,
#     'apparentTemperature': 67.19,
#     'dewPoint': 60,
#     'humidity': 0.78,
#     'pressure': 1022.22,
#     'windSpeed': 17.18,
#     'windGust': 25.67,
#     'windBearing': 99,
#     'cloudCover': 0.89,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 322.08},
#    {'time': 1560153600,
#     'summary': 'Breezy and Mostly Cloudy',
#     'icon': 'wind',
#     'precipIntensity': 0.0014,
#     'precipProbability': 0.11,
#     'precipType': 'rain',
#     'temperature': 67.19,
#     'apparentTemperature': 67.34,
#     'dewPoint': 60.58,
#     'humidity': 0.79,
#     'pressure': 1021.45,
#     'windSpeed': 16.93,
#     'windGust': 25.49,
#     'windBearing': 99,
#     'cloudCover': 0.93,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 323.12},
#    {'time': 1560157200,
#     'summary': 'Breezy and Overcast',
#     'icon': 'wind',
#     'precipIntensity': 0.0022,
#     'precipProbability': 0.14,
#     'precipType': 'rain',
#     'temperature': 67.27,
#     'apparentTemperature': 67.5,
#     'dewPoint': 61.21,
#     'humidity': 0.81,
#     'pressure': 1020.87,
#     'windSpeed': 16.67,
#     'windGust': 25.24,
#     'windBearing': 100,
#     'cloudCover': 0.95,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 323.53},
#    {'time': 1560160800,
#     'summary': 'Breezy and Overcast',
#     'icon': 'wind',
#     'precipIntensity': 0.003,
#     'precipProbability': 0.15,
#     'precipType': 'rain',
#     'temperature': 67.37,
#     'apparentTemperature': 67.69,
#     'dewPoint': 61.91,
#     'humidity': 0.83,
#     'pressure': 1020.54,
#     'windSpeed': 16.48,
#     'windGust': 25.06,
#     'windBearing': 100,
#     'cloudCover': 0.96,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 322.39},
#    {'time': 1560164400,
#     'summary': 'Breezy and Overcast',
#     'icon': 'wind',
#     'precipIntensity': 0.0054,
#     'precipProbability': 0.19,
#     'precipType': 'rain',
#     'temperature': 67.53,
#     'apparentTemperature': 67.95,
#     'dewPoint': 62.65,
#     'humidity': 0.84,
#     'pressure': 1020.41,
#     'windSpeed': 16.35,
#     'windGust': 24.81,
#     'windBearing': 102,
#     'cloudCover': 0.97,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 320.64},
#    {'time': 1560168000,
#     'summary': 'Breezy and Overcast',
#     'icon': 'wind',
#     'precipIntensity': 0.009,
#     'precipProbability': 0.25,
#     'precipType': 'rain',
#     'temperature': 67.87,
#     'apparentTemperature': 68.37,
#     'dewPoint': 63.3,
#     'humidity': 0.85,
#     'pressure': 1020.17,
#     'windSpeed': 16.26,
#     'windGust': 24.49,
#     'windBearing': 102,
#     'cloudCover': 0.98,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 319.39},
#    {'time': 1560171600,
#     'summary': 'Breezy and Overcast',
#     'icon': 'wind',
#     'precipIntensity': 0.0119,
#     'precipProbability': 0.31,
#     'precipType': 'rain',
#     'temperature': 68.4,
#     'apparentTemperature': 68.95,
#     'dewPoint': 63.8,
#     'humidity': 0.85,
#     'pressure': 1019.81,
#     'windSpeed': 16.06,
#     'windGust': 23.67,
#     'windBearing': 103,
#     'cloudCover': 0.98,
#     'uvIndex': 2,
#     'visibility': 9.18,
#     'ozone': 319.39},
#    {'time': 1560175200,
#     'summary': 'Breezy and Overcast',
#     'icon': 'wind',
#     'precipIntensity': 0.0151,
#     'precipProbability': 0.39,
#     'precipType': 'rain',
#     'temperature': 68.99,
#     'apparentTemperature': 69.57,
#     'dewPoint': 64.2,
#     'humidity': 0.85,
#     'pressure': 1019.38,
#     'windSpeed': 15.87,
#     'windGust': 22.8,
#     'windBearing': 103,
#     'cloudCover': 0.98,
#     'uvIndex': 3,
#     'visibility': 7.14,
#     'ozone': 319.91},
#    {'time': 1560178800,
#     'summary': 'Breezy and Overcast',
#     'icon': 'wind',
#     'precipIntensity': 0.0154,
#     'precipProbability': 0.44,
#     'precipType': 'rain',
#     'temperature': 69.1,
#     'apparentTemperature': 69.73,
#     'dewPoint': 64.55,
#     'humidity': 0.85,
#     'pressure': 1018.83,
#     'windSpeed': 15.97,
#     'windGust': 22.87,
#     'windBearing': 103,
#     'cloudCover': 0.99,
#     'uvIndex': 4,
#     'visibility': 5.46,
#     'ozone': 320.33},
#    {'time': 1560182400,
#     'summary': 'Breezy and Overcast',
#     'icon': 'wind',
#     'precipIntensity': 0.0152,
#     'precipProbability': 0.47,
#     'precipType': 'rain',
#     'temperature': 68.98,
#     'apparentTemperature': 69.65,
#     'dewPoint': 64.86,
#     'humidity': 0.87,
#     'pressure': 1018.15,
#     'windSpeed': 16.48,
#     'windGust': 25.17,
#     'windBearing': 107,
#     'cloudCover': 0.99,
#     'uvIndex': 4,
#     'visibility': 4.22,
#     'ozone': 320.33},
#    {'time': 1560186000,
#     'summary': 'Light Rain and Breezy',
#     'icon': 'rain',
#     'precipIntensity': 0.0322,
#     'precipProbability': 0.59,
#     'precipType': 'rain',
#     'temperature': 68.98,
#     'apparentTemperature': 69.69,
#     'dewPoint': 65.11,
#     'humidity': 0.88,
#     'pressure': 1017.38,
#     'windSpeed': 17.25,
#     'windGust': 28.43,
#     'windBearing': 108,
#     'cloudCover': 1,
#     'uvIndex': 4,
#     'visibility': 3.44,
#     'ozone': 320.02},
#    {'time': 1560189600,
#     'summary': 'Light Rain and Breezy',
#     'icon': 'rain',
#     'precipIntensity': 0.0483,
#     'precipProbability': 0.67,
#     'precipType': 'rain',
#     'temperature': 69.46,
#     'apparentTemperature': 70.17,
#     'dewPoint': 65.28,
#     'humidity': 0.87,
#     'pressure': 1016.6,
#     'windSpeed': 17.87,
#     'windGust': 29.98,
#     'windBearing': 110,
#     'cloudCover': 1,
#     'uvIndex': 4,
#     'visibility': 3.39,
#     'ozone': 319.5}]},
#  'daily': {'summary': 'Rain on Monday and Tuesday, with high temperatures bottoming out at 68°F on Thursday.',
#   'icon': 'rain',
#   'data': [{'time': 1559966400,
#     'summary': 'Mostly cloudy starting in the evening and breezy overnight.',
#     'icon': 'wind',
#     'sunriseTime': 1559986116,
#     'sunsetTime': 1560039867,
#     'moonPhase': 0.19,
#     'precipIntensity': 0.0004,
#     'precipIntensityMax': 0.0027,
#     'precipIntensityMaxTime': 1560042000,
#     'precipProbability': 0.1,
#     'precipType': 'rain',
#     'temperatureHigh': 68.65,
#     'temperatureHighTime': 1560027600,
#     'temperatureLow': 66.12,
#     'temperatureLowTime': 1560067200,
#     'apparentTemperatureHigh': 68.65,
#     'apparentTemperatureHighTime': 1560027600,
#     'apparentTemperatureLow': 66.12,
#     'apparentTemperatureLowTime': 1560067200,
#     'dewPoint': 59.33,
#     'humidity': 0.81,
#     'pressure': 1019.73,
#     'windSpeed': 8.36,
#     'windGust': 24.49,
#     'windGustTime': 1560031200,
#     'windBearing': 68,
#     'cloudCover': 0.45,
#     'uvIndex': 9,
#     'uvIndexTime': 1560009600,
#     'visibility': 6.9,
#     'ozone': 326.38,
#     'temperatureMin': 61.42,
#     'temperatureMinTime': 1559984400,
#     'temperatureMax': 68.65,
#     'temperatureMaxTime': 1560027600,
#     'apparentTemperatureMin': 61.57,
#     'apparentTemperatureMinTime': 1559984400,
#     'apparentTemperatureMax': 68.65,
#     'apparentTemperatureMaxTime': 1560027600},
#    {'time': 1560052800,
#     'summary': 'Breezy and mostly cloudy throughout the day.',
#     'icon': 'wind',
#     'sunriseTime': 1560072505,
#     'sunsetTime': 1560126301,
#     'moonPhase': 0.23,
#     'precipIntensity': 0.0002,
#     'precipIntensityMax': 0.0013,
#     'precipIntensityMaxTime': 1560063600,
#     'precipProbability': 0.09,
#     'precipType': 'rain',
#     'temperatureHigh': 70.3,
#     'temperatureHighTime': 1560092400,
#     'temperatureLow': 66.7,
#     'temperatureLowTime': 1560139200,
#     'apparentTemperatureHigh': 70.3,
#     'apparentTemperatureHighTime': 1560092400,
#     'apparentTemperatureLow': 66.7,
#     'apparentTemperatureLowTime': 1560139200,
#     'dewPoint': 58.31,
#     'humidity': 0.71,
#     'pressure': 1025.04,
#     'windSpeed': 16.67,
#     'windGust': 25.86,
#     'windGustTime': 1560092400,
#     'windBearing': 90,
#     'cloudCover': 0.74,
#     'uvIndex': 6,
#     'uvIndexTime': 1560096000,
#     'visibility': 10,
#     'ozone': 330.29,
#     'temperatureMin': 66.12,
#     'temperatureMinTime': 1560067200,
#     'temperatureMax': 70.3,
#     'temperatureMaxTime': 1560092400,
#     'apparentTemperatureMin': 66.12,
#     'apparentTemperatureMinTime': 1560067200,
#     'apparentTemperatureMax': 70.3,
#     'apparentTemperatureMaxTime': 1560092400},
#    {'time': 1560139200,
#     'summary': 'Breezy until evening and light rain in the afternoon.',
#     'icon': 'rain',
#     'sunriseTime': 1560158896,
#     'sunsetTime': 1560212732,
#     'moonPhase': 0.27,
#     'precipIntensity': 0.0124,
#     'precipIntensityMax': 0.0483,
#     'precipIntensityMaxTime': 1560189600,
#     'precipProbability': 0.98,
#     'precipType': 'rain',
#     'temperatureHigh': 70.88,
#     'temperatureHighTime': 1560200400,
#     'temperatureLow': 67.81,
#     'temperatureLowTime': 1560229200,
#     'apparentTemperatureHigh': 71.55,
#     'apparentTemperatureHighTime': 1560200400,
#     'apparentTemperatureLow': 68.48,
#     'apparentTemperatureLowTime': 1560229200,
#     'dewPoint': 63.36,
#     'humidity': 0.83,
#     'pressure': 1017.79,
#     'windSpeed': 14.73,
#     'windGust': 29.98,
#     'windGustTime': 1560189600,
#     'windBearing': 105,
#     'cloudCover': 0.96,
#     'uvIndex': 4,
#     'uvIndexTime': 1560178800,
#     'visibility': 7.67,
#     'ozone': 320.58,
#     'temperatureMin': 66.7,
#     'temperatureMinTime': 1560139200,
#     'temperatureMax': 70.88,
#     'temperatureMaxTime': 1560200400,
#     'apparentTemperatureMin': 66.7,
#     'apparentTemperatureMinTime': 1560139200,
#     'apparentTemperatureMax': 71.55,
#     'apparentTemperatureMaxTime': 1560200400},
#    {'time': 1560225600,
#     'summary': 'Breezy until evening and rain in the morning.',
#     'icon': 'rain',
#     'sunriseTime': 1560245289,
#     'sunsetTime': 1560299162,
#     'moonPhase': 0.3,
#     'precipIntensity': 0.0285,
#     'precipIntensityMax': 0.2116,
#     'precipIntensityMaxTime': 1560254400,
#     'precipProbability': 0.82,
#     'precipType': 'rain',
#     'temperatureHigh': 75.22,
#     'temperatureHighTime': 1560283200,
#     'temperatureLow': 62.81,
#     'temperatureLowTime': 1560330000,
#     'apparentTemperatureHigh': 75.22,
#     'apparentTemperatureHighTime': 1560283200,
#     'apparentTemperatureLow': 62.81,
#     'apparentTemperatureLowTime': 1560330000,
#     'dewPoint': 58.99,
#     'humidity': 0.67,
#     'pressure': 1011.64,
#     'windSpeed': 8.59,
#     'windGust': 27.5,
#     'windGustTime': 1560258000,
#     'windBearing': 297,
#     'cloudCover': 0.6,
#     'uvIndex': 8,
#     'uvIndexTime': 1560276000,
#     'visibility': 8.07,
#     'ozone': 329.2,
#     'temperatureMin': 67.63,
#     'temperatureMinTime': 1560308400,
#     'temperatureMax': 75.22,
#     'temperatureMaxTime': 1560283200,
#     'apparentTemperatureMin': 67.63,
#     'apparentTemperatureMinTime': 1560308400,
#     'apparentTemperatureMax': 75.22,
#     'apparentTemperatureMaxTime': 1560283200},
#    {'time': 1560312000,
#     'summary': 'Mostly cloudy throughout the day.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1560331684,
#     'sunsetTime': 1560385591,
#     'moonPhase': 0.34,
#     'precipIntensity': 0.0001,
#     'precipIntensityMax': 0.0002,
#     'precipIntensityMaxTime': 1560362400,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperatureHigh': 71.86,
#     'temperatureHighTime': 1560362400,
#     'temperatureLow': 65.68,
#     'temperatureLowTime': 1560402000,
#     'apparentTemperatureHigh': 71.86,
#     'apparentTemperatureHighTime': 1560362400,
#     'apparentTemperatureLow': 65.68,
#     'apparentTemperatureLowTime': 1560402000,
#     'dewPoint': 51.58,
#     'humidity': 0.57,
#     'pressure': 1020.67,
#     'windSpeed': 2.87,
#     'windGust': 19.95,
#     'windGustTime': 1560376800,
#     'windBearing': 73,
#     'cloudCover': 0.56,
#     'uvIndex': 7,
#     'uvIndexTime': 1560355200,
#     'visibility': 10,
#     'ozone': 333.12,
#     'temperatureMin': 62.81,
#     'temperatureMinTime': 1560330000,
#     'temperatureMax': 71.86,
#     'temperatureMaxTime': 1560362400,
#     'apparentTemperatureMin': 62.81,
#     'apparentTemperatureMinTime': 1560330000,
#     'apparentTemperatureMax': 71.86,
#     'apparentTemperatureMaxTime': 1560362400},
#    {'time': 1560398400,
#     'summary': 'Overcast throughout the day and breezy until evening.',
#     'icon': 'wind',
#     'sunriseTime': 1560418081,
#     'sunsetTime': 1560472018,
#     'moonPhase': 0.38,
#     'precipIntensity': 0.0052,
#     'precipIntensityMax': 0.0245,
#     'precipIntensityMaxTime': 1560438000,
#     'precipProbability': 0.82,
#     'precipType': 'rain',
#     'temperatureHigh': 67.63,
#     'temperatureHighTime': 1560423600,
#     'temperatureLow': 61.2,
#     'temperatureLowTime': 1560484800,
#     'apparentTemperatureHigh': 67.63,
#     'apparentTemperatureHighTime': 1560423600,
#     'apparentTemperatureLow': 61.2,
#     'apparentTemperatureLowTime': 1560484800,
#     'dewPoint': 57.94,
#     'humidity': 0.77,
#     'pressure': 1013.55,
#     'windSpeed': 14.01,
#     'windGust': 28.4,
#     'windGustTime': 1560427200,
#     'windBearing': 66,
#     'cloudCover': 0.99,
#     'uvIndex': 4,
#     'uvIndexTime': 1560438000,
#     'visibility': 9.7,
#     'ozone': 330.83,
#     'temperatureMin': 61.52,
#     'temperatureMinTime': 1560481200,
#     'temperatureMax': 67.63,
#     'temperatureMaxTime': 1560423600,
#     'apparentTemperatureMin': 61.52,
#     'apparentTemperatureMinTime': 1560481200,
#     'apparentTemperatureMax': 67.63,
#     'apparentTemperatureMaxTime': 1560423600},
#    {'time': 1560484800,
#     'summary': 'Partly cloudy overnight.',
#     'icon': 'partly-cloudy-night',
#     'sunriseTime': 1560504479,
#     'sunsetTime': 1560558443,
#     'moonPhase': 0.41,
#     'precipIntensity': 0.0013,
#     'precipIntensityMax': 0.0074,
#     'precipIntensityMaxTime': 1560484800,
#     'precipProbability': 0.31,
#     'precipType': 'rain',
#     'temperatureHigh': 74.19,
#     'temperatureHighTime': 1560553200,
#     'temperatureLow': 65.78,
#     'temperatureLowTime': 1560585600,
#     'apparentTemperatureHigh': 74.19,
#     'apparentTemperatureHighTime': 1560553200,
#     'apparentTemperatureLow': 65.78,
#     'apparentTemperatureLowTime': 1560585600,
#     'dewPoint': 57.51,
#     'humidity': 0.69,
#     'pressure': 1015.01,
#     'windSpeed': 2.71,
#     'windGust': 26.04,
#     'windGustTime': 1560492000,
#     'windBearing': 260,
#     'cloudCover': 0.2,
#     'uvIndex': 9,
#     'uvIndexTime': 1560531600,
#     'visibility': 10,
#     'ozone': 343.14,
#     'temperatureMin': 61.2,
#     'temperatureMinTime': 1560484800,
#     'temperatureMax': 74.19,
#     'temperatureMaxTime': 1560553200,
#     'apparentTemperatureMin': 61.2,
#     'apparentTemperatureMinTime': 1560484800,
#     'apparentTemperatureMax': 74.19,
#     'apparentTemperatureMaxTime': 1560553200},
#    {'time': 1560571200,
#     'summary': 'Partly cloudy in the morning and breezy overnight.',
#     'icon': 'wind',
#     'sunriseTime': 1560590879,
#     'sunsetTime': 1560644867,
#     'moonPhase': 0.45,
#     'precipIntensity': 0,
#     'precipIntensityMax': 0.0001,
#     'precipIntensityMaxTime': 1560589200,
#     'precipProbability': 0,
#     'temperatureHigh': 77.74,
#     'temperatureHighTime': 1560628800,
#     'temperatureLow': 68.84,
#     'temperatureLowTime': 1560675600,
#     'apparentTemperatureHigh': 77.82,
#     'apparentTemperatureHighTime': 1560628800,
#     'apparentTemperatureLow': 69.2,
#     'apparentTemperatureLowTime': 1560675600,
#     'dewPoint': 60.26,
#     'humidity': 0.67,
#     'pressure': 1018.8,
#     'windSpeed': 9.61,
#     'windGust': 23.96,
#     'windGustTime': 1560654000,
#     'windBearing': 218,
#     'cloudCover': 0.38,
#     'uvIndex': 8,
#     'uvIndexTime': 1560618000,
#     'visibility': 10,
#     'ozone': 341.92,
#     'temperatureMin': 65.78,
#     'temperatureMinTime': 1560585600,
#     'temperatureMax': 77.74,
#     'temperatureMaxTime': 1560628800,
#     'apparentTemperatureMin': 65.78,
#     'apparentTemperatureMinTime': 1560585600,
#     'apparentTemperatureMax': 77.82,
#     'apparentTemperatureMaxTime': 1560628800}]},
#  'flags': {'sources': ['nearest-precip',
#    'nwspa',
#    'cmc',
#    'gfs',
#    'hrrr',
#    'icon',
#    'isd',
#    'madis',
#    'nam',
#    'sref',
#    'darksky'],
#   'nearest-station': 4.019,
#   'units': 'us'},
#  'offset': -4}

# %% [markdown]
# ## 2) What's the current wind speed? How much warmer does it feel than it actually is?
#
# - *Tip: You can do this by browsing through the dictionaries, but it might be easier to read the documentation*
# - *Tip: For the second half: it **is** one temperature, and it **feels** a different temperature. Calculate the difference.*

# %%
newyork['currently']['windSpeed']
# Out:
# 10.4

# %%
newyork['currently']['temperature']-newyork['currently']['apparentTemperature']
# Out:
# 0.0

# %% [markdown]
# ## 3) Today's forecast is the FIRST daily forecast. For the place you decided on above, how much of the moon is currently visible?
#
# - *Tip: This does **not** use the `currently` key.*
# - *Tip: It might be helpful to save the forecast into its own variable*

# %%
newyork['daily']['data'][0]['moonPhase']
# Out:
# 0.19

# %% [markdown]
# ## 4) What's the difference between the high and low temperatures for today?

# %%
newyork['daily']['data'][0]['temperatureHigh']-newyork['daily']['data'][0]['temperatureLow']
# Out:
# 2.530000000000001

# %% [markdown]
# ## 5) Go through the daily forecasts, printing out the next week's worth of predictions.
#
# I'd like to know the **high temperature** for each day, and whether it's **hot, warm, or cold** (based on what temperatures you think are hot, warm or cold).
#
# - *Tip: Is it returning F or C? You can change them by adding `?units=us` or `?units=si` onto the end of the URL.*
# - *Tip: You'll need to use an `if` statement to say whether it is hot, warm or cold.*

# %%
forecast=newyork['daily']['data'][1:8]

for day in forecast:
    print(day['temperatureHigh'])

for day in forecast:
    if day['temperatureHigh']>77:
            print('It is hot.')
    if 68<day['temperatureHigh']<77: 
            print('It is warm.')
    if 68>day['temperatureHigh']:
        print('It is cold.')
# Out:
# 70.3
# 70.88
# 75.22
# 71.86
# 67.63
# 74.19
# 77.74
# It is warm.
# It is warm.
# It is warm.
# It is warm.
# It is cold.
# It is warm.
# It is hot.

# %% [markdown]
# # 6) What will be the hottest day in the next week? What is the high temperature on that day?
#
# It's okay if your result looks like `1453363200`. If you want to be extra-fancy, though, format it as a **real date** - the weird number is called a **UNIX timestamp**, which might help in googling.
#
# - *Tip: It's okay to skip this if it seems too difficult!*

# %%
max(newyork['daily']['data'][1:8]['temperatureHigh'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-4844e9ddcbc5> in <module>
# ----> 1 max(newyork['daily']['data'][1:8]['temperatureHigh'])
#
# TypeError: list indices must be integers or slices, not str

# %% [markdown]
# ## 7) What's the weather looking like for the next 24+ hours in Miami, Florida?
#
# I'd like to know the temperature for every hour, and if it's going to have cloud cover of more than 50% say "{temperature} and cloudy" instead of just the temperature.
#
#
# - *Tip: Be sure to remember how latitude and longitude are done with positive and negative numbers*
# - *Tip: How do you represent "50%" for cloud cover?*

# %%
response=requests.get(f'https://api.darksky.net/forecast/{API_KEY}/25,-80')
miami=response.json()
miami['hourly']['data'][0:23]
# Out:
# [{'time': 1560016800,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0095,
#   'precipProbability': 0.17,
#   'precipType': 'rain',
#   'temperature': 85.79,
#   'apparentTemperature': 96.24,
#   'dewPoint': 76.46,
#   'humidity': 0.74,
#   'pressure': 1014.45,
#   'windSpeed': 10.75,
#   'windGust': 12.73,
#   'windBearing': 208,
#   'cloudCover': 0.36,
#   'uvIndex': 9,
#   'visibility': 9.69,
#   'ozone': 282.2},
#  {'time': 1560020400,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0017,
#   'precipProbability': 0.14,
#   'precipType': 'rain',
#   'temperature': 85.87,
#   'apparentTemperature': 96.28,
#   'dewPoint': 76.38,
#   'humidity': 0.73,
#   'pressure': 1014.14,
#   'windSpeed': 10.35,
#   'windGust': 12.64,
#   'windBearing': 213,
#   'cloudCover': 0.39,
#   'uvIndex': 8,
#   'visibility': 10,
#   'ozone': 282.2},
#  {'time': 1560024000,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0048,
#   'precipProbability': 0.11,
#   'precipType': 'rain',
#   'temperature': 85.89,
#   'apparentTemperature': 96.22,
#   'dewPoint': 76.3,
#   'humidity': 0.73,
#   'pressure': 1013.8,
#   'windSpeed': 9.98,
#   'windGust': 12.46,
#   'windBearing': 213,
#   'cloudCover': 0.49,
#   'uvIndex': 6,
#   'visibility': 10,
#   'ozone': 282.44},
#  {'time': 1560027600,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0018,
#   'precipProbability': 0.08,
#   'precipType': 'rain',
#   'temperature': 85.82,
#   'apparentTemperature': 96.03,
#   'dewPoint': 76.22,
#   'humidity': 0.73,
#   'pressure': 1013.8,
#   'windSpeed': 9.24,
#   'windGust': 11.72,
#   'windBearing': 214,
#   'cloudCover': 0.53,
#   'uvIndex': 4,
#   'visibility': 10,
#   'ozone': 282.79},
#  {'time': 1560031200,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0008,
#   'precipProbability': 0.08,
#   'precipType': 'rain',
#   'temperature': 85.58,
#   'apparentTemperature': 95.58,
#   'dewPoint': 76.15,
#   'humidity': 0.74,
#   'pressure': 1013.68,
#   'windSpeed': 7.85,
#   'windGust': 9.95,
#   'windBearing': 210,
#   'cloudCover': 0.46,
#   'uvIndex': 2,
#   'visibility': 10,
#   'ozone': 283.72},
#  {'time': 1560034800,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0019,
#   'precipProbability': 0.11,
#   'precipType': 'rain',
#   'temperature': 85.32,
#   'apparentTemperature': 95.01,
#   'dewPoint': 75.99,
#   'humidity': 0.74,
#   'pressure': 1013.74,
#   'windSpeed': 6.06,
#   'windGust': 7.26,
#   'windBearing': 197,
#   'cloudCover': 0.36,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 285},
#  {'time': 1560038400,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0015,
#   'precipProbability': 0.11,
#   'precipType': 'rain',
#   'temperature': 84.82,
#   'apparentTemperature': 94.13,
#   'dewPoint': 75.92,
#   'humidity': 0.75,
#   'pressure': 1013.89,
#   'windSpeed': 6,
#   'windGust': 6,
#   'windBearing': 180,
#   'cloudCover': 0.28,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 286.16},
#  {'time': 1560042000,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.0025,
#   'precipProbability': 0.12,
#   'precipType': 'rain',
#   'temperature': 84.31,
#   'apparentTemperature': 93.35,
#   'dewPoint': 75.96,
#   'humidity': 0.76,
#   'pressure': 1014.36,
#   'windSpeed': 6.43,
#   'windGust': 6.43,
#   'windBearing': 176,
#   'cloudCover': 0.36,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 287.42},
#  {'time': 1560045600,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 83.94,
#   'apparentTemperature': 92.85,
#   'dewPoint': 76.07,
#   'humidity': 0.77,
#   'pressure': 1014.74,
#   'windSpeed': 7.99,
#   'windGust': 7.99,
#   'windBearing': 168,
#   'cloudCover': 0.47,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 288.57},
#  {'time': 1560049200,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 83.68,
#   'apparentTemperature': 92.47,
#   'dewPoint': 76.15,
#   'humidity': 0.78,
#   'pressure': 1015.03,
#   'windSpeed': 9.27,
#   'windGust': 9.27,
#   'windBearing': 162,
#   'cloudCover': 0.54,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 289.48},
#  {'time': 1560052800,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.0002,
#   'precipProbability': 0.07,
#   'precipType': 'rain',
#   'temperature': 83.49,
#   'apparentTemperature': 92.22,
#   'dewPoint': 76.23,
#   'humidity': 0.79,
#   'pressure': 1015.06,
#   'windSpeed': 10.09,
#   'windGust': 10.35,
#   'windBearing': 164,
#   'cloudCover': 0.57,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 290.05},
#  {'time': 1560056400,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.0013,
#   'precipProbability': 0.08,
#   'precipType': 'rain',
#   'temperature': 83.21,
#   'apparentTemperature': 91.79,
#   'dewPoint': 76.31,
#   'humidity': 0.8,
#   'pressure': 1014.96,
#   'windSpeed': 10.72,
#   'windGust': 11.45,
#   'windBearing': 168,
#   'cloudCover': 0.53,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 290.17},
#  {'time': 1560060000,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.0025,
#   'precipProbability': 0.08,
#   'precipType': 'rain',
#   'temperature': 82.95,
#   'apparentTemperature': 91.43,
#   'dewPoint': 76.43,
#   'humidity': 0.81,
#   'pressure': 1014.7,
#   'windSpeed': 11.22,
#   'windGust': 12.28,
#   'windBearing': 173,
#   'cloudCover': 0.26,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 290.73},
#  {'time': 1560063600,
#   'summary': 'Humid',
#   'icon': 'clear-night',
#   'precipIntensity': 0.0054,
#   'precipProbability': 0.08,
#   'precipType': 'rain',
#   'temperature': 82.87,
#   'apparentTemperature': 91.39,
#   'dewPoint': 76.54,
#   'humidity': 0.81,
#   'pressure': 1014.58,
#   'windSpeed': 11.81,
#   'windGust': 13.03,
#   'windBearing': 177,
#   'cloudCover': 0.23,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 291.75},
#  {'time': 1560067200,
#   'summary': 'Humid',
#   'icon': 'clear-night',
#   'precipIntensity': 0.0156,
#   'precipProbability': 0.1,
#   'precipType': 'rain',
#   'temperature': 82.91,
#   'apparentTemperature': 91.4,
#   'dewPoint': 76.46,
#   'humidity': 0.81,
#   'pressure': 1014.2,
#   'windSpeed': 12.88,
#   'windGust': 13.85,
#   'windBearing': 177,
#   'cloudCover': 0.24,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 292.77},
#  {'time': 1560070800,
#   'summary': 'Humid',
#   'icon': 'clear-night',
#   'precipIntensity': 0.024,
#   'precipProbability': 0.13,
#   'precipType': 'rain',
#   'temperature': 83,
#   'apparentTemperature': 91.55,
#   'dewPoint': 76.46,
#   'humidity': 0.81,
#   'pressure': 1014.14,
#   'windSpeed': 13.42,
#   'windGust': 14.25,
#   'windBearing': 180,
#   'cloudCover': 0.2,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 293.89},
#  {'time': 1560074400,
#   'summary': 'Humid',
#   'icon': 'clear-night',
#   'precipIntensity': 0.0168,
#   'precipProbability': 0.09,
#   'precipType': 'rain',
#   'temperature': 83.04,
#   'apparentTemperature': 91.48,
#   'dewPoint': 76.31,
#   'humidity': 0.8,
#   'pressure': 1014.33,
#   'windSpeed': 13.58,
#   'windGust': 14.31,
#   'windBearing': 183,
#   'cloudCover': 0.24,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 294.79},
#  {'time': 1560078000,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0085,
#   'precipProbability': 0.07,
#   'precipType': 'rain',
#   'temperature': 83.36,
#   'apparentTemperature': 91.83,
#   'dewPoint': 76.04,
#   'humidity': 0.79,
#   'pressure': 1014.61,
#   'windSpeed': 13.46,
#   'windGust': 14.19,
#   'windBearing': 185,
#   'cloudCover': 0.31,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 295.46},
#  {'time': 1560081600,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0079,
#   'precipProbability': 0.09,
#   'precipType': 'rain',
#   'temperature': 83.54,
#   'apparentTemperature': 91.9,
#   'dewPoint': 75.77,
#   'humidity': 0.78,
#   'pressure': 1015.03,
#   'windSpeed': 13.06,
#   'windGust': 13.88,
#   'windBearing': 186,
#   'cloudCover': 0.35,
#   'uvIndex': 1,
#   'visibility': 10,
#   'ozone': 296.02},
#  {'time': 1560085200,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0094,
#   'precipProbability': 0.12,
#   'precipType': 'rain',
#   'temperature': 83.82,
#   'apparentTemperature': 92.16,
#   'dewPoint': 75.54,
#   'humidity': 0.76,
#   'pressure': 1015.52,
#   'windSpeed': 12.22,
#   'windGust': 13.36,
#   'windBearing': 192,
#   'cloudCover': 0.3,
#   'uvIndex': 2,
#   'visibility': 10,
#   'ozone': 296.13},
#  {'time': 1560088800,
#   'summary': 'Humid',
#   'icon': 'clear-day',
#   'precipIntensity': 0.0119,
#   'precipProbability': 0.15,
#   'precipType': 'rain',
#   'temperature': 83.89,
#   'apparentTemperature': 92.16,
#   'dewPoint': 75.39,
#   'humidity': 0.76,
#   'pressure': 1016.12,
#   'windSpeed': 11.07,
#   'windGust': 12.67,
#   'windBearing': 198,
#   'cloudCover': 0.22,
#   'uvIndex': 5,
#   'visibility': 10,
#   'ozone': 295.9},
#  {'time': 1560092400,
#   'summary': 'Humid',
#   'icon': 'clear-day',
#   'precipIntensity': 0.0138,
#   'precipProbability': 0.16,
#   'precipType': 'rain',
#   'temperature': 83.95,
#   'apparentTemperature': 92.22,
#   'dewPoint': 75.35,
#   'humidity': 0.75,
#   'pressure': 1016.53,
#   'windSpeed': 10.09,
#   'windGust': 12.04,
#   'windBearing': 201,
#   'cloudCover': 0.17,
#   'uvIndex': 7,
#   'visibility': 9.48,
#   'ozone': 295.68},
#  {'time': 1560096000,
#   'summary': 'Humid',
#   'icon': 'clear-day',
#   'precipIntensity': 0.0128,
#   'precipProbability': 0.16,
#   'precipType': 'rain',
#   'temperature': 84.01,
#   'apparentTemperature': 92.61,
#   'dewPoint': 75.69,
#   'humidity': 0.76,
#   'pressure': 1016.6,
#   'windSpeed': 9.47,
#   'windGust': 11.6,
#   'windBearing': 199,
#   'cloudCover': 0.2,
#   'uvIndex': 9,
#   'visibility': 9.11,
#   'ozone': 295.68}]

# %%
miami_forecast=miami['hourly']['data'][0:23]
for day in miami_forecast:
    print(day['temperature'])
# Out:
# 85.79
# 85.87
# 85.89
# 85.82
# 85.58
# 85.32
# 84.82
# 84.31
# 83.94
# 83.68
# 83.49
# 83.21
# 82.95
# 82.87
# 82.91
# 83
# 83.04
# 83.36
# 83.54
# 83.82
# 83.89
# 83.95
# 84.01

# %% [markdown]
# # 8) For the next 24-ish hours in Miami, what percent of the time is the temperature above 85 degrees?
#
# If they give you 48 hours instead of 24, that's okay.
#
# - *Tip: You might want to read up on [looping patterns](http://jonathansoma.com/lede/foundations-2017/classes/data%20structures/looping-patterns/)*

# %%
miami_forecast=miami['hourly']['data'][0:23]
count=0
for day in miami_forecast:
    if day['temperature']>85:
        count=count+1
print(100*count/24,'percent of the time is over 85 degrees.')
# Out:
# 25.0 percent of the time is over 85 degrees.

# %% [markdown]
# ## 9) What was the temperature in Central Park on Christmas Day, 2012? How about 2007? 2005? How far back does the API allow you to go?
#
# - *Tip: You'll need to use UNIX time, which is the number of seconds since January 1, 1970. Google can help you convert a normal date!*
# - *Tip: You'll want to use Forecast.io's "time machine" API, [documentation here](https://darksky.net/dev/docs/time-machine)*

# %%
response=requests.get(f'https://api.darksky.net/forecast/{API_KEY}/40,-73,1356393600')
park=response.json()
park['currently']['temperature']
# Out:
# 40.29

# %%
response=requests.get(f'https://api.darksky.net/forecast/{API_KEY}/40,-73,1198540800')
park=response.json()
park
# Out:
# {'latitude': 40,
#  'longitude': -73,
#  'timezone': 'America/New_York',
#  'currently': {'time': 1198540800, 'uvIndex': 0},
#  'flags': {'sources': ['cmc',
#    'gfs',
#    'hrrr',
#    'icon',
#    'isd',
#    'madis',
#    'nam',
#    'sref'],
#   'nearest-station': 19.469,
#   'units': 'us'},
#  'offset': -5}
