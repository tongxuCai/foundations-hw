# %% [markdown]
# # Dark Sky API (Weather)
#
# Answer the following questions using the [Dark Sky API](https://darksky.net/dev/). I've added three cells for each question but you're free to use more or less! Hold `Shift` and hit `Enter` to run a cell, and use the `+` on the top left to add a new cell to a notebook.
#
# If you spend some time reading the documentation your life will probably be a little bit easier!
#
# ## 0) Import any libraries you might need
#
# - *Tip: We're going to be downloading things from the internet, so we probably need `requests`.*

# %%
import requests

# %% [markdown]
# ## 1) Make a request from the Dark Sky API for where you were born (or lived, or want to visit!).
#
# - *Tip: The URL we used in class was for a place near San Francisco. What was the format of the endpoint that made this happen?*
# - *Tip: Save the URL as a separate variable, and be sure to not have `[` and `]` inside.*
# - *Tip: How is north vs. south and east vs. west latitude/longitude represented? Is it the normal North/South/East/West?*
# - *Tip: You know it's JSON, but Python doesn't! Make sure you aren't trying to deal with plain text.*
# - *Tip: Once you've imported the JSON into a variable, check the timezone's name to make sure it seems like it got the right part of the world!*

# %%
from dotenv import load_dotenv
load_dotenv()
import os
API_KEY=os.getenv('DARKSKY_API_KEY')
API_KEY

# %%
import requests
API_KEY2='9d7e3d75a20e0e7491a8bc3a046011a8'

# %%
response=requests.get(f'https://api.darksky.net/forecast/{API_KEY2}/40,-74')
newyork=response.json()
newyork
# Out:
# {'latitude': 40,
#  'longitude': -74,
#  'timezone': 'America/New_York',
#  'currently': {'time': 1560185473,
#   'summary': 'Rain',
#   'icon': 'rain',
#   'nearestStormDistance': 0,
#   'precipIntensity': 0.0897,
#   'precipIntensityError': 0.034,
#   'precipProbability': 1,
#   'precipType': 'rain',
#   'temperature': 67.9,
#   'apparentTemperature': 68.73,
#   'dewPoint': 65.62,
#   'humidity': 0.92,
#   'pressure': 1016.11,
#   'windSpeed': 11.51,
#   'windGust': 12.17,
#   'windBearing': 130,
#   'cloudCover': 1,
#   'uvIndex': 4,
#   'visibility': 0.48,
#   'ozone': 313.47},
#  'minutely': {'summary': 'Rain stopping in 14 min.',
#   'icon': 'rain',
#   'data': [{'time': 1560185460,
#     'precipIntensity': 0.094,
#     'precipIntensityError': 0.034,
#     'precipProbability': 1,
#     'precipType': 'rain'},
#    {'time': 1560185520,
#     'precipIntensity': 0.074,
#     'precipIntensityError': 0.034,
#     'precipProbability': 1,
#     'precipType': 'rain'},
#    {'time': 1560185580,
#     'precipIntensity': 0.056,
#     'precipIntensityError': 0.032,
#     'precipProbability': 1,
#     'precipType': 'rain'},
#    {'time': 1560185640,
#     'precipIntensity': 0.044,
#     'precipIntensityError': 0.029,
#     'precipProbability': 0.98,
#     'precipType': 'rain'},
#    {'time': 1560185700,
#     'precipIntensity': 0.035,
#     'precipIntensityError': 0.025,
#     'precipProbability': 0.96,
#     'precipType': 'rain'},
#    {'time': 1560185760,
#     'precipIntensity': 0.029,
#     'precipIntensityError': 0.023,
#     'precipProbability': 0.9,
#     'precipType': 'rain'},
#    {'time': 1560185820,
#     'precipIntensity': 0.025,
#     'precipIntensityError': 0.021,
#     'precipProbability': 0.82,
#     'precipType': 'rain'},
#    {'time': 1560185880,
#     'precipIntensity': 0.022,
#     'precipIntensityError': 0.019,
#     'precipProbability': 0.75,
#     'precipType': 'rain'},
#    {'time': 1560185940,
#     'precipIntensity': 0.02,
#     'precipIntensityError': 0.019,
#     'precipProbability': 0.68,
#     'precipType': 'rain'},
#    {'time': 1560186000,
#     'precipIntensity': 0.02,
#     'precipIntensityError': 0.019,
#     'precipProbability': 0.61,
#     'precipType': 'rain'},
#    {'time': 1560186060,
#     'precipIntensity': 0.017,
#     'precipIntensityError': 0.017,
#     'precipProbability': 0.55,
#     'precipType': 'rain'},
#    {'time': 1560186120,
#     'precipIntensity': 0.016,
#     'precipIntensityError': 0.016,
#     'precipProbability': 0.48,
#     'precipType': 'rain'},
#    {'time': 1560186180,
#     'precipIntensity': 0.016,
#     'precipIntensityError': 0.016,
#     'precipProbability': 0.42,
#     'precipType': 'rain'},
#    {'time': 1560186240,
#     'precipIntensity': 0.014,
#     'precipIntensityError': 0.015,
#     'precipProbability': 0.39,
#     'precipType': 'rain'},
#    {'time': 1560186300,
#     'precipIntensity': 0.013,
#     'precipIntensityError': 0.014,
#     'precipProbability': 0.34,
#     'precipType': 'rain'},
#    {'time': 1560186360,
#     'precipIntensity': 0.013,
#     'precipIntensityError': 0.014,
#     'precipProbability': 0.3,
#     'precipType': 'rain'},
#    {'time': 1560186420,
#     'precipIntensity': 0.012,
#     'precipIntensityError': 0.013,
#     'precipProbability': 0.28,
#     'precipType': 'rain'},
#    {'time': 1560186480,
#     'precipIntensity': 0.012,
#     'precipIntensityError': 0.012,
#     'precipProbability': 0.25,
#     'precipType': 'rain'},
#    {'time': 1560186540,
#     'precipIntensity': 0.01,
#     'precipIntensityError': 0.011,
#     'precipProbability': 0.23,
#     'precipType': 'rain'},
#    {'time': 1560186600,
#     'precipIntensity': 0.011,
#     'precipIntensityError': 0.012,
#     'precipProbability': 0.2,
#     'precipType': 'rain'},
#    {'time': 1560186660,
#     'precipIntensity': 0.01,
#     'precipIntensityError': 0.011,
#     'precipProbability': 0.19,
#     'precipType': 'rain'},
#    {'time': 1560186720,
#     'precipIntensity': 0.01,
#     'precipIntensityError': 0.01,
#     'precipProbability': 0.16,
#     'precipType': 'rain'},
#    {'time': 1560186780,
#     'precipIntensity': 0.01,
#     'precipIntensityError': 0.01,
#     'precipProbability': 0.14,
#     'precipType': 'rain'},
#    {'time': 1560186840,
#     'precipIntensity': 0.01,
#     'precipIntensityError': 0.01,
#     'precipProbability': 0.12,
#     'precipType': 'rain'},
#    {'time': 1560186900,
#     'precipIntensity': 0.009,
#     'precipIntensityError': 0.009,
#     'precipProbability': 0.12,
#     'precipType': 'rain'},
#    {'time': 1560186960,
#     'precipIntensity': 0.01,
#     'precipIntensityError': 0.01,
#     'precipProbability': 0.11,
#     'precipType': 'rain'},
#    {'time': 1560187020,
#     'precipIntensity': 0.01,
#     'precipIntensityError': 0.009,
#     'precipProbability': 0.1,
#     'precipType': 'rain'},
#    {'time': 1560187080,
#     'precipIntensity': 0.01,
#     'precipIntensityError': 0.008,
#     'precipProbability': 0.09,
#     'precipType': 'rain'},
#    {'time': 1560187140,
#     'precipIntensity': 0.01,
#     'precipIntensityError': 0.008,
#     'precipProbability': 0.09,
#     'precipType': 'rain'},
#    {'time': 1560187200,
#     'precipIntensity': 0.009,
#     'precipIntensityError': 0.008,
#     'precipProbability': 0.08,
#     'precipType': 'rain'},
#    {'time': 1560187260,
#     'precipIntensity': 0.01,
#     'precipIntensityError': 0.008,
#     'precipProbability': 0.07,
#     'precipType': 'rain'},
#    {'time': 1560187320,
#     'precipIntensity': 0.01,
#     'precipIntensityError': 0.008,
#     'precipProbability': 0.07,
#     'precipType': 'rain'},
#    {'time': 1560187380,
#     'precipIntensity': 0.01,
#     'precipIntensityError': 0.008,
#     'precipProbability': 0.07,
#     'precipType': 'rain'},
#    {'time': 1560187440,
#     'precipIntensity': 0.01,
#     'precipIntensityError': 0.007,
#     'precipProbability': 0.06,
#     'precipType': 'rain'},
#    {'time': 1560187500,
#     'precipIntensity': 0.009,
#     'precipIntensityError': 0.007,
#     'precipProbability': 0.05,
#     'precipType': 'rain'},
#    {'time': 1560187560,
#     'precipIntensity': 0.01,
#     'precipIntensityError': 0.007,
#     'precipProbability': 0.05,
#     'precipType': 'rain'},
#    {'time': 1560187620,
#     'precipIntensity': 0.011,
#     'precipIntensityError': 0.007,
#     'precipProbability': 0.05,
#     'precipType': 'rain'},
#    {'time': 1560187680,
#     'precipIntensity': 0.01,
#     'precipIntensityError': 0.006,
#     'precipProbability': 0.05,
#     'precipType': 'rain'},
#    {'time': 1560187740,
#     'precipIntensity': 0.01,
#     'precipIntensityError': 0.006,
#     'precipProbability': 0.05,
#     'precipType': 'rain'},
#    {'time': 1560187800,
#     'precipIntensity': 0.01,
#     'precipIntensityError': 0.006,
#     'precipProbability': 0.04,
#     'precipType': 'rain'},
#    {'time': 1560187860,
#     'precipIntensity': 0.01,
#     'precipIntensityError': 0.006,
#     'precipProbability': 0.04,
#     'precipType': 'rain'},
#    {'time': 1560187920,
#     'precipIntensity': 0.01,
#     'precipIntensityError': 0.007,
#     'precipProbability': 0.04,
#     'precipType': 'rain'},
#    {'time': 1560187980,
#     'precipIntensity': 0.01,
#     'precipIntensityError': 0.006,
#     'precipProbability': 0.04,
#     'precipType': 'rain'},
#    {'time': 1560188040,
#     'precipIntensity': 0.01,
#     'precipIntensityError': 0.007,
#     'precipProbability': 0.04,
#     'precipType': 'rain'},
#    {'time': 1560188100,
#     'precipIntensity': 0.01,
#     'precipIntensityError': 0.007,
#     'precipProbability': 0.04,
#     'precipType': 'rain'},
#    {'time': 1560188160,
#     'precipIntensity': 0.01,
#     'precipIntensityError': 0.006,
#     'precipProbability': 0.04,
#     'precipType': 'rain'},
#    {'time': 1560188220,
#     'precipIntensity': 0.01,
#     'precipIntensityError': 0.006,
#     'precipProbability': 0.03,
#     'precipType': 'rain'},
#    {'time': 1560188280, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560188340,
#     'precipIntensity': 0.009,
#     'precipIntensityError': 0.006,
#     'precipProbability': 0.03,
#     'precipType': 'rain'},
#    {'time': 1560188400,
#     'precipIntensity': 0.01,
#     'precipIntensityError': 0.008,
#     'precipProbability': 0.03,
#     'precipType': 'rain'},
#    {'time': 1560188460,
#     'precipIntensity': 0.009,
#     'precipIntensityError': 0.006,
#     'precipProbability': 0.02,
#     'precipType': 'rain'},
#    {'time': 1560188520,
#     'precipIntensity': 0.01,
#     'precipIntensityError': 0.007,
#     'precipProbability': 0.03,
#     'precipType': 'rain'},
#    {'time': 1560188580,
#     'precipIntensity': 0.009,
#     'precipIntensityError': 0.006,
#     'precipProbability': 0.02,
#     'precipType': 'rain'},
#    {'time': 1560188640,
#     'precipIntensity': 0.009,
#     'precipIntensityError': 0.006,
#     'precipProbability': 0.02,
#     'precipType': 'rain'},
#    {'time': 1560188700,
#     'precipIntensity': 0.009,
#     'precipIntensityError': 0.006,
#     'precipProbability': 0.02,
#     'precipType': 'rain'},
#    {'time': 1560188760,
#     'precipIntensity': 0.008,
#     'precipIntensityError': 0.006,
#     'precipProbability': 0.02,
#     'precipType': 'rain'},
#    {'time': 1560188820,
#     'precipIntensity': 0.009,
#     'precipIntensityError': 0.006,
#     'precipProbability': 0.02,
#     'precipType': 'rain'},
#    {'time': 1560188880,
#     'precipIntensity': 0.009,
#     'precipIntensityError': 0.006,
#     'precipProbability': 0.02,
#     'precipType': 'rain'},
#    {'time': 1560188940, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560189000, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560189060,
#     'precipIntensity': 0.009,
#     'precipIntensityError': 0.006,
#     'precipProbability': 0.01,
#     'precipType': 'rain'}]},
#  'hourly': {'summary': 'Rain starting tonight, continuing until tomorrow morning, and breezy starting tomorrow morning.',
#   'icon': 'rain',
#   'data': [{'time': 1560182400,
#     'summary': 'Foggy',
#     'icon': 'fog',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 67.83,
#     'apparentTemperature': 68.63,
#     'dewPoint': 65.39,
#     'humidity': 0.92,
#     'pressure': 1016.7,
#     'windSpeed': 12.94,
#     'windGust': 17.37,
#     'windBearing': 113,
#     'cloudCover': 1,
#     'uvIndex': 4,
#     'visibility': 0.79,
#     'ozone': 312.48},
#    {'time': 1560186000,
#     'summary': 'Light Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.0124,
#     'precipProbability': 1,
#     'precipType': 'rain',
#     'temperature': 67.91,
#     'apparentTemperature': 68.75,
#     'dewPoint': 65.66,
#     'humidity': 0.93,
#     'pressure': 1016.01,
#     'windSpeed': 11.38,
#     'windGust': 11.38,
#     'windBearing': 133,
#     'cloudCover': 1,
#     'uvIndex': 4,
#     'visibility': 0.43,
#     'ozone': 313.64},
#    {'time': 1560189600,
#     'summary': 'Foggy',
#     'icon': 'fog',
#     'precipIntensity': 0.003,
#     'precipProbability': 0.04,
#     'precipType': 'rain',
#     'temperature': 68.35,
#     'apparentTemperature': 69.2,
#     'dewPoint': 65.9,
#     'humidity': 0.92,
#     'pressure': 1015.31,
#     'windSpeed': 11.22,
#     'windGust': 11.22,
#     'windBearing': 151,
#     'cloudCover': 1,
#     'uvIndex': 4,
#     'visibility': 0.71,
#     'ozone': 314.8},
#    {'time': 1560193200,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 69.13,
#     'apparentTemperature': 69.96,
#     'dewPoint': 65.94,
#     'humidity': 0.9,
#     'pressure': 1014.88,
#     'windSpeed': 13.49,
#     'windGust': 13.49,
#     'windBearing': 152,
#     'cloudCover': 0.96,
#     'uvIndex': 4,
#     'visibility': 2.53,
#     'ozone': 316.58},
#    {'time': 1560196800,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0029,
#     'precipProbability': 0.36,
#     'precipType': 'rain',
#     'temperature': 69.91,
#     'apparentTemperature': 70.69,
#     'dewPoint': 65.85,
#     'humidity': 0.87,
#     'pressure': 1014.48,
#     'windSpeed': 14.65,
#     'windGust': 17.96,
#     'windBearing': 150,
#     'cloudCover': 0.93,
#     'uvIndex': 3,
#     'visibility': 4.14,
#     'ozone': 318.56},
#    {'time': 1560200400,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.003,
#     'precipProbability': 0.37,
#     'precipType': 'rain',
#     'temperature': 70.43,
#     'apparentTemperature': 71.19,
#     'dewPoint': 65.87,
#     'humidity': 0.86,
#     'pressure': 1013.92,
#     'windSpeed': 14.41,
#     'windGust': 19.08,
#     'windBearing': 152,
#     'cloudCover': 0.9,
#     'uvIndex': 2,
#     'visibility': 4.81,
#     'ozone': 319.81},
#    {'time': 1560204000,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0023,
#     'precipProbability': 0.36,
#     'precipType': 'rain',
#     'temperature': 70.12,
#     'apparentTemperature': 70.89,
#     'dewPoint': 65.85,
#     'humidity': 0.86,
#     'pressure': 1013.62,
#     'windSpeed': 13.88,
#     'windGust': 19.28,
#     'windBearing': 150,
#     'cloudCover': 0.91,
#     'uvIndex': 1,
#     'visibility': 5.08,
#     'ozone': 319.5},
#    {'time': 1560207600,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0.0046,
#     'precipProbability': 0.4,
#     'precipType': 'rain',
#     'temperature': 69.74,
#     'apparentTemperature': 70.52,
#     'dewPoint': 65.81,
#     'humidity': 0.87,
#     'pressure': 1013.18,
#     'windSpeed': 13.33,
#     'windGust': 18,
#     'windBearing': 147,
#     'cloudCover': 0.97,
#     'uvIndex': 0,
#     'visibility': 5.1,
#     'ozone': 318.35},
#    {'time': 1560211200,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0.0061,
#     'precipProbability': 0.42,
#     'precipType': 'rain',
#     'temperature': 69.62,
#     'apparentTemperature': 70.4,
#     'dewPoint': 65.79,
#     'humidity': 0.88,
#     'pressure': 1012.91,
#     'windSpeed': 13.12,
#     'windGust': 18.26,
#     'windBearing': 149,
#     'cloudCover': 0.99,
#     'uvIndex': 0,
#     'visibility': 5.05,
#     'ozone': 317.42},
#    {'time': 1560214800,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0.004,
#     'precipProbability': 0.37,
#     'precipType': 'rain',
#     'temperature': 69.42,
#     'apparentTemperature': 70.2,
#     'dewPoint': 65.69,
#     'humidity': 0.88,
#     'pressure': 1012.54,
#     'windSpeed': 12.79,
#     'windGust': 18.23,
#     'windBearing': 150,
#     'cloudCover': 0.99,
#     'uvIndex': 0,
#     'visibility': 5.02,
#     'ozone': 316.69},
#    {'time': 1560218400,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0.0052,
#     'precipProbability': 0.4,
#     'precipType': 'rain',
#     'temperature': 69.28,
#     'apparentTemperature': 70.05,
#     'dewPoint': 65.67,
#     'humidity': 0.88,
#     'pressure': 1012.18,
#     'windSpeed': 13.12,
#     'windGust': 19.25,
#     'windBearing': 153,
#     'cloudCover': 0.99,
#     'uvIndex': 0,
#     'visibility': 4.92,
#     'ozone': 316.06},
#    {'time': 1560222000,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0.017,
#     'precipProbability': 0.57,
#     'precipType': 'rain',
#     'temperature': 69.36,
#     'apparentTemperature': 70.14,
#     'dewPoint': 65.75,
#     'humidity': 0.88,
#     'pressure': 1011.82,
#     'windSpeed': 12.88,
#     'windGust': 18.42,
#     'windBearing': 158,
#     'cloudCover': 0.99,
#     'uvIndex': 0,
#     'visibility': 4.7,
#     'ozone': 315.74},
#    {'time': 1560225600,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0.0032,
#     'precipProbability': 0.39,
#     'precipType': 'rain',
#     'temperature': 69.61,
#     'apparentTemperature': 70.42,
#     'dewPoint': 65.97,
#     'humidity': 0.88,
#     'pressure': 1011.08,
#     'windSpeed': 12.7,
#     'windGust': 17.51,
#     'windBearing': 167,
#     'cloudCover': 0.98,
#     'uvIndex': 0,
#     'visibility': 4.3,
#     'ozone': 315.64},
#    {'time': 1560229200,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0084,
#     'precipProbability': 0.52,
#     'precipType': 'rain',
#     'temperature': 70.01,
#     'apparentTemperature': 70.88,
#     'dewPoint': 66.47,
#     'humidity': 0.89,
#     'pressure': 1010.2,
#     'windSpeed': 13.27,
#     'windGust': 19.28,
#     'windBearing': 180,
#     'cloudCover': 0.92,
#     'uvIndex': 0,
#     'visibility': 3.8,
#     'ozone': 315.74},
#    {'time': 1560232800,
#     'summary': 'Light Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.0206,
#     'precipProbability': 0.65,
#     'precipType': 'rain',
#     'temperature': 70.03,
#     'apparentTemperature': 70.94,
#     'dewPoint': 66.78,
#     'humidity': 0.89,
#     'pressure': 1009.54,
#     'windSpeed': 12.85,
#     'windGust': 17.25,
#     'windBearing': 190,
#     'cloudCover': 0.94,
#     'uvIndex': 0,
#     'visibility': 3.25,
#     'ozone': 315.85},
#    {'time': 1560236400,
#     'summary': 'Light Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.0425,
#     'precipProbability': 0.74,
#     'precipType': 'rain',
#     'temperature': 70.44,
#     'apparentTemperature': 71.4,
#     'dewPoint': 67.25,
#     'humidity': 0.9,
#     'pressure': 1008.75,
#     'windSpeed': 12.16,
#     'windGust': 13.42,
#     'windBearing': 217,
#     'cloudCover': 1,
#     'uvIndex': 0,
#     'visibility': 3.64,
#     'ozone': 316.06},
#    {'time': 1560240000,
#     'summary': 'Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.0583,
#     'precipProbability': 0.75,
#     'precipType': 'rain',
#     'temperature': 70.68,
#     'apparentTemperature': 71.67,
#     'dewPoint': 67.55,
#     'humidity': 0.9,
#     'pressure': 1008.34,
#     'windSpeed': 11.51,
#     'windGust': 11.95,
#     'windBearing': 245,
#     'cloudCover': 1,
#     'uvIndex': 0,
#     'visibility': 2.86,
#     'ozone': 316.37},
#    {'time': 1560243600,
#     'summary': 'Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.0606,
#     'precipProbability': 0.75,
#     'precipType': 'rain',
#     'temperature': 70.7,
#     'apparentTemperature': 71.67,
#     'dewPoint': 67.43,
#     'humidity': 0.89,
#     'pressure': 1008.19,
#     'windSpeed': 11.69,
#     'windGust': 12.7,
#     'windBearing': 237,
#     'cloudCover': 1,
#     'uvIndex': 0,
#     'visibility': 2.4,
#     'ozone': 317.21},
#    {'time': 1560247200,
#     'summary': 'Light Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.0403,
#     'precipProbability': 0.7,
#     'precipType': 'rain',
#     'temperature': 70.37,
#     'apparentTemperature': 71.25,
#     'dewPoint': 66.71,
#     'humidity': 0.88,
#     'pressure': 1008.36,
#     'windSpeed': 13.52,
#     'windGust': 18,
#     'windBearing': 165,
#     'cloudCover': 1,
#     'uvIndex': 0,
#     'visibility': 2.19,
#     'ozone': 318.25},
#    {'time': 1560250800,
#     'summary': 'Light Rain and Breezy',
#     'icon': 'rain',
#     'precipIntensity': 0.0215,
#     'precipProbability': 0.65,
#     'precipType': 'rain',
#     'temperature': 69.59,
#     'apparentTemperature': 70.29,
#     'dewPoint': 65.21,
#     'humidity': 0.86,
#     'pressure': 1008.79,
#     'windSpeed': 16.06,
#     'windGust': 25.64,
#     'windBearing': 33,
#     'cloudCover': 1,
#     'uvIndex': 0,
#     'visibility': 2.23,
#     'ozone': 319.6},
#    {'time': 1560254400,
#     'summary': 'Breezy and Overcast',
#     'icon': 'wind',
#     'precipIntensity': 0.0153,
#     'precipProbability': 0.48,
#     'precipType': 'rain',
#     'temperature': 69.09,
#     'apparentTemperature': 69.52,
#     'dewPoint': 63.17,
#     'humidity': 0.81,
#     'pressure': 1009.33,
#     'windSpeed': 18.03,
#     'windGust': 30.82,
#     'windBearing': 300,
#     'cloudCover': 1,
#     'uvIndex': 1,
#     'visibility': 3.05,
#     'ozone': 322.39},
#    {'time': 1560258000,
#     'summary': 'Breezy and Overcast',
#     'icon': 'wind',
#     'precipIntensity': 0.0081,
#     'precipProbability': 0.12,
#     'precipType': 'rain',
#     'temperature': 69.27,
#     'apparentTemperature': 69.42,
#     'dewPoint': 61.02,
#     'humidity': 0.75,
#     'pressure': 1010.01,
#     'windSpeed': 18.75,
#     'windGust': 31.05,
#     'windBearing': 281,
#     'cloudCover': 0.94,
#     'uvIndex': 2,
#     'visibility': 6.57,
#     'ozone': 328.03},
#    {'time': 1560261600,
#     'summary': 'Breezy and Mostly Cloudy',
#     'icon': 'wind',
#     'precipIntensity': 0.0017,
#     'precipProbability': 0.04,
#     'precipType': 'rain',
#     'temperature': 69.77,
#     'apparentTemperature': 69.77,
#     'dewPoint': 59.06,
#     'humidity': 0.69,
#     'pressure': 1010.77,
#     'windSpeed': 19.02,
#     'windGust': 29,
#     'windBearing': 324,
#     'cloudCover': 0.86,
#     'uvIndex': 3,
#     'visibility': 10,
#     'ozone': 335.03},
#    {'time': 1560265200,
#     'summary': 'Breezy and Mostly Cloudy',
#     'icon': 'wind',
#     'precipIntensity': 0.0002,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperature': 70.06,
#     'apparentTemperature': 70.06,
#     'dewPoint': 57.55,
#     'humidity': 0.65,
#     'pressure': 1011.53,
#     'windSpeed': 19.08,
#     'windGust': 27.1,
#     'windBearing': 320,
#     'cloudCover': 0.78,
#     'uvIndex': 4,
#     'visibility': 10,
#     'ozone': 340.57},
#    {'time': 1560268800,
#     'summary': 'Breezy and Mostly Cloudy',
#     'icon': 'wind',
#     'precipIntensity': 0.0002,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 70.67,
#     'apparentTemperature': 70.67,
#     'dewPoint': 56.59,
#     'humidity': 0.61,
#     'pressure': 1012.23,
#     'windSpeed': 18.65,
#     'windGust': 25.89,
#     'windBearing': 315,
#     'cloudCover': 0.71,
#     'uvIndex': 5,
#     'visibility': 10,
#     'ozone': 344.08},
#    {'time': 1560272400,
#     'summary': 'Breezy and Mostly Cloudy',
#     'icon': 'wind',
#     'precipIntensity': 0.0003,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 71.6,
#     'apparentTemperature': 71.6,
#     'dewPoint': 55.9,
#     'humidity': 0.58,
#     'pressure': 1012.91,
#     'windSpeed': 17.8,
#     'windGust': 24.63,
#     'windBearing': 318,
#     'cloudCover': 0.65,
#     'uvIndex': 6,
#     'visibility': 10,
#     'ozone': 346.28},
#    {'time': 1560276000,
#     'summary': 'Breezy and Partly Cloudy',
#     'icon': 'wind',
#     'precipIntensity': 0.0003,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 73.21,
#     'apparentTemperature': 73.21,
#     'dewPoint': 55.25,
#     'humidity': 0.53,
#     'pressure': 1013.47,
#     'windSpeed': 17.12,
#     'windGust': 23.43,
#     'windBearing': 321,
#     'cloudCover': 0.54,
#     'uvIndex': 6,
#     'visibility': 10,
#     'ozone': 346.58},
#    {'time': 1560279600,
#     'summary': 'Breezy and Partly Cloudy',
#     'icon': 'wind',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 74.57,
#     'apparentTemperature': 74.57,
#     'dewPoint': 54.59,
#     'humidity': 0.5,
#     'pressure': 1013.74,
#     'windSpeed': 16.73,
#     'windGust': 22.34,
#     'windBearing': 323,
#     'cloudCover': 0.38,
#     'uvIndex': 6,
#     'visibility': 10,
#     'ozone': 343.77},
#    {'time': 1560283200,
#     'summary': 'Breezy',
#     'icon': 'wind',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 75.59,
#     'apparentTemperature': 75.59,
#     'dewPoint': 53.99,
#     'humidity': 0.47,
#     'pressure': 1013.86,
#     'windSpeed': 16.51,
#     'windGust': 21.34,
#     'windBearing': 325,
#     'cloudCover': 0.17,
#     'uvIndex': 5,
#     'visibility': 10,
#     'ozone': 339.06},
#    {'time': 1560286800,
#     'summary': 'Breezy',
#     'icon': 'wind',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 76.33,
#     'apparentTemperature': 76.33,
#     'dewPoint': 53.5,
#     'humidity': 0.45,
#     'pressure': 1014.14,
#     'windSpeed': 16.22,
#     'windGust': 20.46,
#     'windBearing': 327,
#     'cloudCover': 0.01,
#     'uvIndex': 3,
#     'visibility': 10,
#     'ozone': 335.44},
#    {'time': 1560290400,
#     'summary': 'Breezy',
#     'icon': 'wind',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 75.95,
#     'apparentTemperature': 75.95,
#     'dewPoint': 53.2,
#     'humidity': 0.45,
#     'pressure': 1014.67,
#     'windSpeed': 15.72,
#     'windGust': 19.55,
#     'windBearing': 327,
#     'cloudCover': 0,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 334.02},
#    {'time': 1560294000,
#     'summary': 'Breezy',
#     'icon': 'wind',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 74.76,
#     'apparentTemperature': 74.76,
#     'dewPoint': 53,
#     'humidity': 0.47,
#     'pressure': 1015.35,
#     'windSpeed': 15.15,
#     'windGust': 18.75,
#     'windBearing': 327,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 333.62},
#    {'time': 1560297600,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 73.3,
#     'apparentTemperature': 73.3,
#     'dewPoint': 52.7,
#     'humidity': 0.49,
#     'pressure': 1016.05,
#     'windSpeed': 14.78,
#     'windGust': 18.75,
#     'windBearing': 327,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 333.21},
#    {'time': 1560301200,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 71.88,
#     'apparentTemperature': 71.88,
#     'dewPoint': 52.14,
#     'humidity': 0.5,
#     'pressure': 1016.85,
#     'windSpeed': 14.99,
#     'windGust': 20.49,
#     'windBearing': 331,
#     'cloudCover': 0.03,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 332.61},
#    {'time': 1560304800,
#     'summary': 'Breezy',
#     'icon': 'wind',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 70.35,
#     'apparentTemperature': 70.35,
#     'dewPoint': 51.45,
#     'humidity': 0.51,
#     'pressure': 1017.67,
#     'windSpeed': 15.43,
#     'windGust': 23.01,
#     'windBearing': 335,
#     'cloudCover': 0.06,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 332.1},
#    {'time': 1560308400,
#     'summary': 'Breezy',
#     'icon': 'wind',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 69.09,
#     'apparentTemperature': 69.09,
#     'dewPoint': 50.87,
#     'humidity': 0.52,
#     'pressure': 1018.38,
#     'windSpeed': 15.5,
#     'windGust': 24.13,
#     'windBearing': 339,
#     'cloudCover': 0.08,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 331.39},
#    {'time': 1560312000,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 67.97,
#     'apparentTemperature': 67.97,
#     'dewPoint': 50.48,
#     'humidity': 0.54,
#     'pressure': 1018.76,
#     'windSpeed': 14.71,
#     'windGust': 22.76,
#     'windBearing': 340,
#     'cloudCover': 0.09,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 330.07},
#    {'time': 1560315600,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 66.86,
#     'apparentTemperature': 66.86,
#     'dewPoint': 50.21,
#     'humidity': 0.55,
#     'pressure': 1018.99,
#     'windSpeed': 13.55,
#     'windGust': 20.05,
#     'windBearing': 342,
#     'cloudCover': 0.1,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 328.64},
#    {'time': 1560319200,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 65.75,
#     'apparentTemperature': 65.75,
#     'dewPoint': 50,
#     'humidity': 0.57,
#     'pressure': 1019.26,
#     'windSpeed': 12.46,
#     'windGust': 17.41,
#     'windBearing': 342,
#     'cloudCover': 0.1,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 327.52},
#    {'time': 1560322800,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 64.59,
#     'apparentTemperature': 64.59,
#     'dewPoint': 49.91,
#     'humidity': 0.59,
#     'pressure': 1019.65,
#     'windSpeed': 11.72,
#     'windGust': 15.15,
#     'windBearing': 340,
#     'cloudCover': 0.11,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 327.22},
#    {'time': 1560326400,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 63.56,
#     'apparentTemperature': 63.56,
#     'dewPoint': 49.91,
#     'humidity': 0.61,
#     'pressure': 1020.13,
#     'windSpeed': 11.04,
#     'windGust': 13,
#     'windBearing': 339,
#     'cloudCover': 0.12,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 327.22},
#    {'time': 1560330000,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 63.1,
#     'apparentTemperature': 63.1,
#     'dewPoint': 50.05,
#     'humidity': 0.62,
#     'pressure': 1020.58,
#     'windSpeed': 10.41,
#     'windGust': 11.31,
#     'windBearing': 340,
#     'cloudCover': 0.14,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 327.32},
#    {'time': 1560333600,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 63.62,
#     'apparentTemperature': 63.62,
#     'dewPoint': 50.42,
#     'humidity': 0.62,
#     'pressure': 1020.99,
#     'windSpeed': 9.66,
#     'windGust': 10.29,
#     'windBearing': 345,
#     'cloudCover': 0.17,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 327.32},
#    {'time': 1560337200,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 64.97,
#     'apparentTemperature': 64.97,
#     'dewPoint': 50.88,
#     'humidity': 0.6,
#     'pressure': 1021.41,
#     'windSpeed': 8.96,
#     'windGust': 9.75,
#     'windBearing': 354,
#     'cloudCover': 0.19,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 327.32},
#    {'time': 1560340800,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0.0003,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 66.5,
#     'apparentTemperature': 66.5,
#     'dewPoint': 51.32,
#     'humidity': 0.58,
#     'pressure': 1021.79,
#     'windSpeed': 8.43,
#     'windGust': 9.41,
#     'windBearing': 7,
#     'cloudCover': 0.23,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 327.11},
#    {'time': 1560344400,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0003,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 67.88,
#     'apparentTemperature': 67.88,
#     'dewPoint': 51.6,
#     'humidity': 0.56,
#     'pressure': 1022.05,
#     'windSpeed': 8.13,
#     'windGust': 9.02,
#     'windBearing': 29,
#     'cloudCover': 0.31,
#     'uvIndex': 3,
#     'visibility': 10,
#     'ozone': 326.3},
#    {'time': 1560348000,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 69.1,
#     'apparentTemperature': 69.1,
#     'dewPoint': 51.86,
#     'humidity': 0.54,
#     'pressure': 1022.22,
#     'windSpeed': 8.02,
#     'windGust': 8.79,
#     'windBearing': 56,
#     'cloudCover': 0.43,
#     'uvIndex': 5,
#     'visibility': 10,
#     'ozone': 325.27},
#    {'time': 1560351600,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 69.81,
#     'apparentTemperature': 69.81,
#     'dewPoint': 52.16,
#     'humidity': 0.54,
#     'pressure': 1022.31,
#     'windSpeed': 8.18,
#     'windGust': 9.1,
#     'windBearing': 78,
#     'cloudCover': 0.51,
#     'uvIndex': 6,
#     'visibility': 10,
#     'ozone': 324.55},
#    {'time': 1560355200,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 69.69,
#     'apparentTemperature': 69.69,
#     'dewPoint': 52.59,
#     'humidity': 0.55,
#     'pressure': 1022.26,
#     'windSpeed': 8.71,
#     'windGust': 10.15,
#     'windBearing': 98,
#     'cloudCover': 0.63,
#     'uvIndex': 6,
#     'visibility': 10,
#     'ozone': 324.35}]},
#  'daily': {'summary': 'Rain throughout the week, with high temperatures bottoming out at 70°F on Wednesday.',
#   'icon': 'rain',
#   'data': [{'time': 1560139200,
#     'summary': 'Light rain in the morning and overnight.',
#     'icon': 'rain',
#     'sunriseTime': 1560158896,
#     'sunsetTime': 1560212732,
#     'moonPhase': 0.27,
#     'precipIntensity': 0.0063,
#     'precipIntensityMax': 0.0427,
#     'precipIntensityMaxTime': 1560178800,
#     'precipProbability': 1,
#     'precipType': 'rain',
#     'temperatureHigh': 70.43,
#     'temperatureHighTime': 1560200400,
#     'temperatureLow': 69.09,
#     'temperatureLowTime': 1560254400,
#     'apparentTemperatureHigh': 71.19,
#     'apparentTemperatureHighTime': 1560200400,
#     'apparentTemperatureLow': 69.52,
#     'apparentTemperatureLowTime': 1560254400,
#     'dewPoint': 63.69,
#     'humidity': 0.87,
#     'pressure': 1017.02,
#     'windSpeed': 10.34,
#     'windGust': 19.28,
#     'windGustTime': 1560204000,
#     'windBearing': 119,
#     'cloudCover': 0.99,
#     'uvIndex': 4,
#     'uvIndexTime': 1560178800,
#     'visibility': 5.73,
#     'ozone': 314.82,
#     'temperatureMin': 65.44,
#     'temperatureMinTime': 1560146400,
#     'temperatureMax': 70.43,
#     'temperatureMaxTime': 1560200400,
#     'apparentTemperatureMin': 65.44,
#     'apparentTemperatureMinTime': 1560146400,
#     'apparentTemperatureMax': 71.19,
#     'apparentTemperatureMaxTime': 1560200400},
#    {'time': 1560225600,
#     'summary': 'Rain in the morning and breezy until evening.',
#     'icon': 'rain',
#     'sunriseTime': 1560245289,
#     'sunsetTime': 1560299162,
#     'moonPhase': 0.3,
#     'precipIntensity': 0.0118,
#     'precipIntensityMax': 0.0606,
#     'precipIntensityMaxTime': 1560243600,
#     'precipProbability': 0.9,
#     'precipType': 'rain',
#     'temperatureHigh': 76.33,
#     'temperatureHighTime': 1560286800,
#     'temperatureLow': 63.1,
#     'temperatureLowTime': 1560330000,
#     'apparentTemperatureHigh': 76.33,
#     'apparentTemperatureHighTime': 1560286800,
#     'apparentTemperatureLow': 63.1,
#     'apparentTemperatureLowTime': 1560330000,
#     'dewPoint': 59.06,
#     'humidity': 0.67,
#     'pressure': 1012.26,
#     'windSpeed': 9.62,
#     'windGust': 31.05,
#     'windGustTime': 1560258000,
#     'windBearing': 308,
#     'cloudCover': 0.59,
#     'uvIndex': 6,
#     'uvIndexTime': 1560272400,
#     'visibility': 7.26,
#     'ozone': 329.7,
#     'temperatureMin': 69.09,
#     'temperatureMinTime': 1560254400,
#     'temperatureMax': 76.33,
#     'temperatureMaxTime': 1560286800,
#     'apparentTemperatureMin': 69.09,
#     'apparentTemperatureMinTime': 1560308400,
#     'apparentTemperatureMax': 76.33,
#     'apparentTemperatureMaxTime': 1560286800},
#    {'time': 1560312000,
#     'summary': 'Mostly cloudy throughout the day and breezy overnight.',
#     'icon': 'wind',
#     'sunriseTime': 1560331684,
#     'sunsetTime': 1560385591,
#     'moonPhase': 0.34,
#     'precipIntensity': 0.0001,
#     'precipIntensityMax': 0.0003,
#     'precipIntensityMaxTime': 1560340800,
#     'precipProbability': 0.04,
#     'precipType': 'rain',
#     'temperatureHigh': 69.81,
#     'temperatureHighTime': 1560351600,
#     'temperatureLow': 65.78,
#     'temperatureLowTime': 1560427200,
#     'apparentTemperatureHigh': 69.81,
#     'apparentTemperatureHighTime': 1560351600,
#     'apparentTemperatureLow': 66.09,
#     'apparentTemperatureLowTime': 1560427200,
#     'dewPoint': 52.94,
#     'humidity': 0.6,
#     'pressure': 1020.7,
#     'windSpeed': 4.31,
#     'windGust': 23.99,
#     'windGustTime': 1560394800,
#     'windBearing': 77,
#     'cloudCover': 0.56,
#     'uvIndex': 6,
#     'uvIndexTime': 1560351600,
#     'visibility': 10,
#     'ozone': 326.13,
#     'temperatureMin': 63.1,
#     'temperatureMinTime': 1560330000,
#     'temperatureMax': 69.81,
#     'temperatureMaxTime': 1560351600,
#     'apparentTemperatureMin': 63.1,
#     'apparentTemperatureMinTime': 1560330000,
#     'apparentTemperatureMax': 69.81,
#     'apparentTemperatureMaxTime': 1560351600},
#    {'time': 1560398400,
#     'summary': 'Breezy until afternoon and heavy rain in the morning and overnight.',
#     'icon': 'rain',
#     'sunriseTime': 1560418081,
#     'sunsetTime': 1560472018,
#     'moonPhase': 0.38,
#     'precipIntensity': 0.0561,
#     'precipIntensityMax': 0.3309,
#     'precipIntensityMaxTime': 1560427200,
#     'precipProbability': 0.96,
#     'precipType': 'rain',
#     'temperatureHigh': 71.52,
#     'temperatureHighTime': 1560463200,
#     'temperatureLow': 63.45,
#     'temperatureLowTime': 1560506400,
#     'apparentTemperatureHigh': 72.02,
#     'apparentTemperatureHighTime': 1560463200,
#     'apparentTemperatureLow': 63.45,
#     'apparentTemperatureLowTime': 1560506400,
#     'dewPoint': 62.11,
#     'humidity': 0.81,
#     'pressure': 1009.21,
#     'windSpeed': 11.85,
#     'windGust': 37.53,
#     'windGustTime': 1560427200,
#     'windBearing': 136,
#     'cloudCover': 0.78,
#     'uvIndex': 4,
#     'uvIndexTime': 1560438000,
#     'visibility': 8.43,
#     'ozone': 327.95,
#     'temperatureMin': 65.78,
#     'temperatureMinTime': 1560427200,
#     'temperatureMax': 71.52,
#     'temperatureMaxTime': 1560463200,
#     'apparentTemperatureMin': 66.09,
#     'apparentTemperatureMinTime': 1560427200,
#     'apparentTemperatureMax': 72.02,
#     'apparentTemperatureMaxTime': 1560463200},
#    {'time': 1560484800,
#     'summary': 'Breezy until evening.',
#     'icon': 'wind',
#     'sunriseTime': 1560504479,
#     'sunsetTime': 1560558443,
#     'moonPhase': 0.41,
#     'precipIntensity': 0.0035,
#     'precipIntensityMax': 0.0455,
#     'precipIntensityMaxTime': 1560484800,
#     'precipProbability': 0.31,
#     'precipType': 'rain',
#     'temperatureHigh': 73.88,
#     'temperatureHighTime': 1560549600,
#     'temperatureLow': 65.33,
#     'temperatureLowTime': 1560585600,
#     'apparentTemperatureHigh': 73.88,
#     'apparentTemperatureHighTime': 1560549600,
#     'apparentTemperatureLow': 65.33,
#     'apparentTemperatureLowTime': 1560585600,
#     'dewPoint': 53.04,
#     'humidity': 0.58,
#     'pressure': 1014.08,
#     'windSpeed': 13.47,
#     'windGust': 33.5,
#     'windGustTime': 1560517200,
#     'windBearing': 262,
#     'cloudCover': 0.04,
#     'uvIndex': 8,
#     'uvIndexTime': 1560531600,
#     'visibility': 9.79,
#     'ozone': 371.02,
#     'temperatureMin': 63.45,
#     'temperatureMinTime': 1560506400,
#     'temperatureMax': 73.88,
#     'temperatureMaxTime': 1560549600,
#     'apparentTemperatureMin': 63.45,
#     'apparentTemperatureMinTime': 1560506400,
#     'apparentTemperatureMax': 73.88,
#     'apparentTemperatureMaxTime': 1560549600},
#    {'time': 1560571200,
#     'summary': 'Breezy in the evening and mostly cloudy overnight.',
#     'icon': 'wind',
#     'sunriseTime': 1560590879,
#     'sunsetTime': 1560644867,
#     'moonPhase': 0.45,
#     'precipIntensity': 0.0001,
#     'precipIntensityMax': 0.0003,
#     'precipIntensityMaxTime': 1560654000,
#     'precipProbability': 0.04,
#     'precipType': 'rain',
#     'temperatureHigh': 76.31,
#     'temperatureHighTime': 1560628800,
#     'temperatureLow': 69.05,
#     'temperatureLowTime': 1560675600,
#     'apparentTemperatureHigh': 76.31,
#     'apparentTemperatureHighTime': 1560628800,
#     'apparentTemperatureLow': 69.49,
#     'apparentTemperatureLowTime': 1560675600,
#     'dewPoint': 55.98,
#     'humidity': 0.59,
#     'pressure': 1017.98,
#     'windSpeed': 11.95,
#     'windGust': 20.83,
#     'windGustTime': 1560571200,
#     'windBearing': 232,
#     'cloudCover': 0.07,
#     'uvIndex': 9,
#     'uvIndexTime': 1560618000,
#     'visibility': 10,
#     'ozone': 353.69,
#     'temperatureMin': 65.33,
#     'temperatureMinTime': 1560585600,
#     'temperatureMax': 76.31,
#     'temperatureMaxTime': 1560628800,
#     'apparentTemperatureMin': 65.33,
#     'apparentTemperatureMinTime': 1560585600,
#     'apparentTemperatureMax': 76.31,
#     'apparentTemperatureMaxTime': 1560628800},
#    {'time': 1560657600,
#     'summary': 'Mostly cloudy throughout the day and breezy overnight.',
#     'icon': 'wind',
#     'sunriseTime': 1560677282,
#     'sunsetTime': 1560731289,
#     'moonPhase': 0.48,
#     'precipIntensity': 0.0031,
#     'precipIntensityMax': 0.0133,
#     'precipIntensityMaxTime': 1560679200,
#     'precipProbability': 0.66,
#     'precipType': 'rain',
#     'temperatureHigh': 74.99,
#     'temperatureHighTime': 1560711600,
#     'temperatureLow': 68.92,
#     'temperatureLowTime': 1560751200,
#     'apparentTemperatureHigh': 74.99,
#     'apparentTemperatureHighTime': 1560711600,
#     'apparentTemperatureLow': 69.21,
#     'apparentTemperatureLowTime': 1560751200,
#     'dewPoint': 61.06,
#     'humidity': 0.69,
#     'pressure': 1015.13,
#     'windSpeed': 5.32,
#     'windGust': 25.82,
#     'windGustTime': 1560740400,
#     'windBearing': 231,
#     'cloudCover': 0.83,
#     'uvIndex': 6,
#     'uvIndexTime': 1560704400,
#     'visibility': 10,
#     'ozone': 334.31,
#     'temperatureMin': 69.05,
#     'temperatureMinTime': 1560675600,
#     'temperatureMax': 74.99,
#     'temperatureMaxTime': 1560711600,
#     'apparentTemperatureMin': 69.49,
#     'apparentTemperatureMinTime': 1560675600,
#     'apparentTemperatureMax': 74.99,
#     'apparentTemperatureMaxTime': 1560711600},
#    {'time': 1560744000,
#     'summary': 'Overcast throughout the day.',
#     'icon': 'cloudy',
#     'sunriseTime': 1560763686,
#     'sunsetTime': 1560817709,
#     'moonPhase': 0.52,
#     'precipIntensity': 0.0135,
#     'precipIntensityMax': 0.0443,
#     'precipIntensityMaxTime': 1560805200,
#     'precipProbability': 0.96,
#     'precipType': 'rain',
#     'temperatureHigh': 78.91,
#     'temperatureHighTime': 1560805200,
#     'temperatureLow': 69.43,
#     'temperatureLowTime': 1560855600,
#     'apparentTemperatureHigh': 79.41,
#     'apparentTemperatureHighTime': 1560805200,
#     'apparentTemperatureLow': 69.44,
#     'apparentTemperatureLowTime': 1560855600,
#     'dewPoint': 63.59,
#     'humidity': 0.69,
#     'pressure': 1015.1,
#     'windSpeed': 11.55,
#     'windGust': 28.73,
#     'windGustTime': 1560747600,
#     'windBearing': 196,
#     'cloudCover': 0.96,
#     'uvIndex': 4,
#     'uvIndexTime': 1560783600,
#     'visibility': 6.94,
#     'ozone': 324.29,
#     'temperatureMin': 68.92,
#     'temperatureMinTime': 1560751200,
#     'temperatureMax': 78.91,
#     'temperatureMaxTime': 1560805200,
#     'apparentTemperatureMin': 69.21,
#     'apparentTemperatureMinTime': 1560751200,
#     'apparentTemperatureMax': 79.41,
#     'apparentTemperatureMaxTime': 1560805200}]},
#  'flags': {'sources': ['nearest-precip',
#    'nwspa',
#    'cmc',
#    'gfs',
#    'hrrr',
#    'icon',
#    'isd',
#    'madis',
#    'nam',
#    'sref',
#    'darksky'],
#   'nearest-station': 4.019,
#   'units': 'us'},
#  'offset': -4}

# %% [markdown]
# ## 2) What's the current wind speed? How much warmer does it feel than it actually is?
#
# - *Tip: You can do this by browsing through the dictionaries, but it might be easier to read the documentation*
# - *Tip: For the second half: it **is** one temperature, and it **feels** a different temperature. Calculate the difference.*

# %%
newyork['currently']['windSpeed']
# Out:
# 10.4

# %%
newyork['currently']['temperature']-newyork['currently']['apparentTemperature']
# Out:
# 0.0

# %% [markdown]
# ## 3) Today's forecast is the FIRST daily forecast. For the place you decided on above, how much of the moon is currently visible?
#
# - *Tip: This does **not** use the `currently` key.*
# - *Tip: It might be helpful to save the forecast into its own variable*

# %%
newyork['daily']['data'][0]['moonPhase']
# Out:
# 0.19

# %% [markdown]
# ## 4) What's the difference between the high and low temperatures for today?

# %%
newyork['daily']['data'][0]['temperatureHigh']-newyork['daily']['data'][0]['temperatureLow']
# Out:
# 2.530000000000001

# %% [markdown]
# ## 5) Go through the daily forecasts, printing out the next week's worth of predictions.
#
# I'd like to know the **high temperature** for each day, and whether it's **hot, warm, or cold** (based on what temperatures you think are hot, warm or cold).
#
# - *Tip: Is it returning F or C? You can change them by adding `?units=us` or `?units=si` onto the end of the URL.*
# - *Tip: You'll need to use an `if` statement to say whether it is hot, warm or cold.*

# %%
forecast=newyork['daily']['data'][1:8]

for day in forecast:
    print(day['temperatureHigh'])

for day in forecast:
    if day['temperatureHigh']>77:
            print('It is hot.')
    if 68<day['temperatureHigh']<77: 
            print('It is warm.')
    if 68>day['temperatureHigh']:
        print('It is cold.')
# Out:
# 70.3
# 70.88
# 75.22
# 71.86
# 67.63
# 74.19
# 77.74
# It is warm.
# It is warm.
# It is warm.
# It is warm.
# It is cold.
# It is warm.
# It is hot.

# %% [markdown]
# # 6) What will be the hottest day in the next week? What is the high temperature on that day?
#
# It's okay if your result looks like `1453363200`. If you want to be extra-fancy, though, format it as a **real date** - the weird number is called a **UNIX timestamp**, which might help in googling.
#
# - *Tip: It's okay to skip this if it seems too difficult!*

# %%
max(newyork['daily']['data'][1:8]['temperatureHigh'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-4844e9ddcbc5> in <module>
# ----> 1 max(newyork['daily']['data'][1:8]['temperatureHigh'])
#
# TypeError: list indices must be integers or slices, not str

# %% [markdown]
# ## 7) What's the weather looking like for the next 24+ hours in Miami, Florida?
#
# I'd like to know the temperature for every hour, and if it's going to have cloud cover of more than 50% say "{temperature} and cloudy" instead of just the temperature.
#
#
# - *Tip: Be sure to remember how latitude and longitude are done with positive and negative numbers*
# - *Tip: How do you represent "50%" for cloud cover?*

# %%
response=requests.get(f'https://api.darksky.net/forecast/{API_KEY2}/25,-80')
miami=response.json()
miami['hourly']['data'][0:23]
# Out:
# [{'time': 1560016800,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0095,
#   'precipProbability': 0.17,
#   'precipType': 'rain',
#   'temperature': 85.79,
#   'apparentTemperature': 96.24,
#   'dewPoint': 76.46,
#   'humidity': 0.74,
#   'pressure': 1014.45,
#   'windSpeed': 10.75,
#   'windGust': 12.73,
#   'windBearing': 208,
#   'cloudCover': 0.36,
#   'uvIndex': 9,
#   'visibility': 9.69,
#   'ozone': 282.2},
#  {'time': 1560020400,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0017,
#   'precipProbability': 0.14,
#   'precipType': 'rain',
#   'temperature': 85.87,
#   'apparentTemperature': 96.28,
#   'dewPoint': 76.38,
#   'humidity': 0.73,
#   'pressure': 1014.14,
#   'windSpeed': 10.35,
#   'windGust': 12.64,
#   'windBearing': 213,
#   'cloudCover': 0.39,
#   'uvIndex': 8,
#   'visibility': 10,
#   'ozone': 282.2},
#  {'time': 1560024000,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0048,
#   'precipProbability': 0.11,
#   'precipType': 'rain',
#   'temperature': 85.89,
#   'apparentTemperature': 96.22,
#   'dewPoint': 76.3,
#   'humidity': 0.73,
#   'pressure': 1013.8,
#   'windSpeed': 9.98,
#   'windGust': 12.46,
#   'windBearing': 213,
#   'cloudCover': 0.49,
#   'uvIndex': 6,
#   'visibility': 10,
#   'ozone': 282.44},
#  {'time': 1560027600,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0018,
#   'precipProbability': 0.08,
#   'precipType': 'rain',
#   'temperature': 85.82,
#   'apparentTemperature': 96.03,
#   'dewPoint': 76.22,
#   'humidity': 0.73,
#   'pressure': 1013.8,
#   'windSpeed': 9.24,
#   'windGust': 11.72,
#   'windBearing': 214,
#   'cloudCover': 0.53,
#   'uvIndex': 4,
#   'visibility': 10,
#   'ozone': 282.79},
#  {'time': 1560031200,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0008,
#   'precipProbability': 0.08,
#   'precipType': 'rain',
#   'temperature': 85.58,
#   'apparentTemperature': 95.58,
#   'dewPoint': 76.15,
#   'humidity': 0.74,
#   'pressure': 1013.68,
#   'windSpeed': 7.85,
#   'windGust': 9.95,
#   'windBearing': 210,
#   'cloudCover': 0.46,
#   'uvIndex': 2,
#   'visibility': 10,
#   'ozone': 283.72},
#  {'time': 1560034800,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0019,
#   'precipProbability': 0.11,
#   'precipType': 'rain',
#   'temperature': 85.32,
#   'apparentTemperature': 95.01,
#   'dewPoint': 75.99,
#   'humidity': 0.74,
#   'pressure': 1013.74,
#   'windSpeed': 6.06,
#   'windGust': 7.26,
#   'windBearing': 197,
#   'cloudCover': 0.36,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 285},
#  {'time': 1560038400,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0015,
#   'precipProbability': 0.11,
#   'precipType': 'rain',
#   'temperature': 84.82,
#   'apparentTemperature': 94.13,
#   'dewPoint': 75.92,
#   'humidity': 0.75,
#   'pressure': 1013.89,
#   'windSpeed': 6,
#   'windGust': 6,
#   'windBearing': 180,
#   'cloudCover': 0.28,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 286.16},
#  {'time': 1560042000,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.0025,
#   'precipProbability': 0.12,
#   'precipType': 'rain',
#   'temperature': 84.31,
#   'apparentTemperature': 93.35,
#   'dewPoint': 75.96,
#   'humidity': 0.76,
#   'pressure': 1014.36,
#   'windSpeed': 6.43,
#   'windGust': 6.43,
#   'windBearing': 176,
#   'cloudCover': 0.36,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 287.42},
#  {'time': 1560045600,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 83.94,
#   'apparentTemperature': 92.85,
#   'dewPoint': 76.07,
#   'humidity': 0.77,
#   'pressure': 1014.74,
#   'windSpeed': 7.99,
#   'windGust': 7.99,
#   'windBearing': 168,
#   'cloudCover': 0.47,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 288.57},
#  {'time': 1560049200,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 83.68,
#   'apparentTemperature': 92.47,
#   'dewPoint': 76.15,
#   'humidity': 0.78,
#   'pressure': 1015.03,
#   'windSpeed': 9.27,
#   'windGust': 9.27,
#   'windBearing': 162,
#   'cloudCover': 0.54,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 289.48},
#  {'time': 1560052800,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.0002,
#   'precipProbability': 0.07,
#   'precipType': 'rain',
#   'temperature': 83.49,
#   'apparentTemperature': 92.22,
#   'dewPoint': 76.23,
#   'humidity': 0.79,
#   'pressure': 1015.06,
#   'windSpeed': 10.09,
#   'windGust': 10.35,
#   'windBearing': 164,
#   'cloudCover': 0.57,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 290.05},
#  {'time': 1560056400,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.0013,
#   'precipProbability': 0.08,
#   'precipType': 'rain',
#   'temperature': 83.21,
#   'apparentTemperature': 91.79,
#   'dewPoint': 76.31,
#   'humidity': 0.8,
#   'pressure': 1014.96,
#   'windSpeed': 10.72,
#   'windGust': 11.45,
#   'windBearing': 168,
#   'cloudCover': 0.53,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 290.17},
#  {'time': 1560060000,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.0025,
#   'precipProbability': 0.08,
#   'precipType': 'rain',
#   'temperature': 82.95,
#   'apparentTemperature': 91.43,
#   'dewPoint': 76.43,
#   'humidity': 0.81,
#   'pressure': 1014.7,
#   'windSpeed': 11.22,
#   'windGust': 12.28,
#   'windBearing': 173,
#   'cloudCover': 0.26,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 290.73},
#  {'time': 1560063600,
#   'summary': 'Humid',
#   'icon': 'clear-night',
#   'precipIntensity': 0.0054,
#   'precipProbability': 0.08,
#   'precipType': 'rain',
#   'temperature': 82.87,
#   'apparentTemperature': 91.39,
#   'dewPoint': 76.54,
#   'humidity': 0.81,
#   'pressure': 1014.58,
#   'windSpeed': 11.81,
#   'windGust': 13.03,
#   'windBearing': 177,
#   'cloudCover': 0.23,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 291.75},
#  {'time': 1560067200,
#   'summary': 'Humid',
#   'icon': 'clear-night',
#   'precipIntensity': 0.0156,
#   'precipProbability': 0.1,
#   'precipType': 'rain',
#   'temperature': 82.91,
#   'apparentTemperature': 91.4,
#   'dewPoint': 76.46,
#   'humidity': 0.81,
#   'pressure': 1014.2,
#   'windSpeed': 12.88,
#   'windGust': 13.85,
#   'windBearing': 177,
#   'cloudCover': 0.24,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 292.77},
#  {'time': 1560070800,
#   'summary': 'Humid',
#   'icon': 'clear-night',
#   'precipIntensity': 0.024,
#   'precipProbability': 0.13,
#   'precipType': 'rain',
#   'temperature': 83,
#   'apparentTemperature': 91.55,
#   'dewPoint': 76.46,
#   'humidity': 0.81,
#   'pressure': 1014.14,
#   'windSpeed': 13.42,
#   'windGust': 14.25,
#   'windBearing': 180,
#   'cloudCover': 0.2,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 293.89},
#  {'time': 1560074400,
#   'summary': 'Humid',
#   'icon': 'clear-night',
#   'precipIntensity': 0.0168,
#   'precipProbability': 0.09,
#   'precipType': 'rain',
#   'temperature': 83.04,
#   'apparentTemperature': 91.48,
#   'dewPoint': 76.31,
#   'humidity': 0.8,
#   'pressure': 1014.33,
#   'windSpeed': 13.58,
#   'windGust': 14.31,
#   'windBearing': 183,
#   'cloudCover': 0.24,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 294.79},
#  {'time': 1560078000,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0085,
#   'precipProbability': 0.07,
#   'precipType': 'rain',
#   'temperature': 83.36,
#   'apparentTemperature': 91.83,
#   'dewPoint': 76.04,
#   'humidity': 0.79,
#   'pressure': 1014.61,
#   'windSpeed': 13.46,
#   'windGust': 14.19,
#   'windBearing': 185,
#   'cloudCover': 0.31,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 295.46},
#  {'time': 1560081600,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0079,
#   'precipProbability': 0.09,
#   'precipType': 'rain',
#   'temperature': 83.54,
#   'apparentTemperature': 91.9,
#   'dewPoint': 75.77,
#   'humidity': 0.78,
#   'pressure': 1015.03,
#   'windSpeed': 13.06,
#   'windGust': 13.88,
#   'windBearing': 186,
#   'cloudCover': 0.35,
#   'uvIndex': 1,
#   'visibility': 10,
#   'ozone': 296.02},
#  {'time': 1560085200,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0094,
#   'precipProbability': 0.12,
#   'precipType': 'rain',
#   'temperature': 83.82,
#   'apparentTemperature': 92.16,
#   'dewPoint': 75.54,
#   'humidity': 0.76,
#   'pressure': 1015.52,
#   'windSpeed': 12.22,
#   'windGust': 13.36,
#   'windBearing': 192,
#   'cloudCover': 0.3,
#   'uvIndex': 2,
#   'visibility': 10,
#   'ozone': 296.13},
#  {'time': 1560088800,
#   'summary': 'Humid',
#   'icon': 'clear-day',
#   'precipIntensity': 0.0119,
#   'precipProbability': 0.15,
#   'precipType': 'rain',
#   'temperature': 83.89,
#   'apparentTemperature': 92.16,
#   'dewPoint': 75.39,
#   'humidity': 0.76,
#   'pressure': 1016.12,
#   'windSpeed': 11.07,
#   'windGust': 12.67,
#   'windBearing': 198,
#   'cloudCover': 0.22,
#   'uvIndex': 5,
#   'visibility': 10,
#   'ozone': 295.9},
#  {'time': 1560092400,
#   'summary': 'Humid',
#   'icon': 'clear-day',
#   'precipIntensity': 0.0138,
#   'precipProbability': 0.16,
#   'precipType': 'rain',
#   'temperature': 83.95,
#   'apparentTemperature': 92.22,
#   'dewPoint': 75.35,
#   'humidity': 0.75,
#   'pressure': 1016.53,
#   'windSpeed': 10.09,
#   'windGust': 12.04,
#   'windBearing': 201,
#   'cloudCover': 0.17,
#   'uvIndex': 7,
#   'visibility': 9.48,
#   'ozone': 295.68},
#  {'time': 1560096000,
#   'summary': 'Humid',
#   'icon': 'clear-day',
#   'precipIntensity': 0.0128,
#   'precipProbability': 0.16,
#   'precipType': 'rain',
#   'temperature': 84.01,
#   'apparentTemperature': 92.61,
#   'dewPoint': 75.69,
#   'humidity': 0.76,
#   'pressure': 1016.6,
#   'windSpeed': 9.47,
#   'windGust': 11.6,
#   'windBearing': 199,
#   'cloudCover': 0.2,
#   'uvIndex': 9,
#   'visibility': 9.11,
#   'ozone': 295.68}]

# %%
miami_forecast=miami['hourly']['data'][0:23]
for day in miami_forecast:
    print(day['temperature'])
# Out:
# 85.79
# 85.87
# 85.89
# 85.82
# 85.58
# 85.32
# 84.82
# 84.31
# 83.94
# 83.68
# 83.49
# 83.21
# 82.95
# 82.87
# 82.91
# 83
# 83.04
# 83.36
# 83.54
# 83.82
# 83.89
# 83.95
# 84.01

# %% [markdown]
# # 8) For the next 24-ish hours in Miami, what percent of the time is the temperature above 85 degrees?
#
# If they give you 48 hours instead of 24, that's okay.
#
# - *Tip: You might want to read up on [looping patterns](http://jonathansoma.com/lede/foundations-2017/classes/data%20structures/looping-patterns/)*

# %%
miami_forecast=miami['hourly']['data'][0:23]
count=0
for day in miami_forecast:
    if day['temperature']>85:
        count=count+1
print(100*count/24,'percent of the time is over 85 degrees.')
# Out:
# 25.0 percent of the time is over 85 degrees.

# %% [markdown]
# ## 9) What was the temperature in Central Park on Christmas Day, 2012? How about 2007? 2005? How far back does the API allow you to go?
#
# - *Tip: You'll need to use UNIX time, which is the number of seconds since January 1, 1970. Google can help you convert a normal date!*
# - *Tip: You'll want to use Forecast.io's "time machine" API, [documentation here](https://darksky.net/dev/docs/time-machine)*

# %%
response=requests.get(f'https://api.darksky.net/forecast/{API_KEY2}/40,-73,1356393600')
park=response.json()
park['currently']['temperature']
# Out:
# 40.29

# %%
response=requests.get(f'https://api.darksky.net/forecast/{API_KEY2}/40,-73,1198540800')
park=response.json()
park
# Out:
# {'latitude': 40,
#  'longitude': -73,
#  'timezone': 'America/New_York',
#  'currently': {'time': 1198540800, 'uvIndex': 0},
#  'flags': {'sources': ['cmc',
#    'gfs',
#    'hrrr',
#    'icon',
#    'isd',
#    'madis',
#    'nam',
#    'sref'],
#   'nearest-station': 19.469,
#   'units': 'us'},
#  'offset': -5}
